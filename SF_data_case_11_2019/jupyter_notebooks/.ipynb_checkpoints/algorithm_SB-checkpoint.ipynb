# %% [markdown]
# # McDonalds and Starbucks: what would be better as meals for teens?
# <b>2. Starbucks (SB) breakfasts & dinners menu-maker: a combinatorial approach</b>

# %% [markdown]
# The main idea is to create "meaningful" (no repetitions, should not contain only food or only drinks) combinations from the menu of each restaurant. Second step is selection of combinations that meet certain criteria.
#
# <b>Advantages:</b>
# - Allows not only answer the question "which restaurant is better" but also offer the most diverse menu, regardless of the selected restaurant.
# - Criteria (both statistical and individual indicators) could be flexibly setted, changed, results could be quickly saved and compared.
# - This approach can be considered as a sketch, proof of concept for further development of the solution.

# %% [markdown]
# DONE:
# 0. Insert cells with official norm values and their processings from <b>data_processing</b> notebook.
# 1. Normalize values of all menu items by dividing them on <b>meal_norm</b> values dict.
# 2. Restrict whole dataset to <b>only McD items</b>
# 3. Select item groups of breakfast / dinner (according to format [1-st food item, 2-nd food item, 3-rd drink item]).
# 4. Build a <b>meal-maker</b> row-applied function (args: item groups) which returns a dataset of combitations of items from passed item groups as argument.
# 5. Calculating a <b>total values</b> (calories, fat... e t.c.): sum of values for each item in certain meal combination across all generated meal combinations.
# 6. Calculating <b>MEAN</b> and <b>STDEV</b> as metrics of caloric and nutrition balace for each meal combination across totals (calories, fat... e t.c.). If <b>MEAN</b> ≈ 1 and <b>STDEV</b> ≈ 0 --> meal combination is well fitted to norms.
# 7. Append the portion of result (after selection another item groups in p.3 with futher processing) to final <b>'results_all'</b> df.
# 8. Write <b>'results_all'</b> in .csv.

# %%
# required imports
import pandas as pd
from itertools import product, combinations
import matplotlib
# %matplotlib inline

# %% [markdown]
# ### Official norms

# %%
# Dict with actual norms (from official document-1)
norms = {}

f = open ('actual_norms.txt')

for line in f:
    line = line.strip().split(',')
    norms[line[0]] = line[1]
    
del norms['Item']
norms
# Out:
# {'Energy(kcal)': '2900',
#  'Fat(g)': '97',
#  'Carbohydrates(g)': '421',
#  'Fiber(g)': '20',
#  'Protein(g)': '87',
#  'Sodium(g)': '1.3'}

# %%
# (From official document-2): 
# -breakfast + dinner = 20-25% + 30-35% daily energy value respectively --> 
# 25% and 35% (max due to sports competitions)
# -breakfast + dinner = 55-60% total daily nutrients value --> 
# 25% and 35% (max due to sports competitions)
# (only breakfast and dinner mentioned in the task)
# Let's assume that breakfast / dinner share are equal --> 
# meal_norm (30% and 30% respectively)

# calculating weighted norms:

meal_norm = {}

for key, value in norms.items():
    meal_norm[key] = float(value)*0.3
    
# sum_norm dict for data filtering (del items which contain greater values):   
sum_norm = {key:float(value)*0.6 for key, value in norms.items()}
    
print (meal_norm)
print (sum_norm)
# Out:
# {'Energy(kcal)': 870.0, 'Fat(g)': 29.099999999999998, 'Carbohydrates(g)': 126.3, 'Fiber(g)': 6.0, 'Protein(g)': 26.099999999999998, 'Sodium(g)': 0.39}
# {'Energy(kcal)': 1740.0, 'Fat(g)': 58.199999999999996, 'Carbohydrates(g)': 252.6, 'Fiber(g)': 12.0, 'Protein(g)': 52.199999999999996, 'Sodium(g)': 0.78}

# %%
# Earlier in 'data_processing' notebook we increased the sodium sum 
# (breakfast + dinner) norm from 0.78 to 1.0, i.e. +0.22. 
# In turns it increases sodium meal_norm by 0.11 g. Dicts should be updated: 
meal_norm['Sodium(g)'] += 0.11
sum_norm['Sodium(g)'] += 0.22
print (meal_norm)
print (sum_norm)
# Out:
# {'Energy(kcal)': 870.0, 'Fat(g)': 29.099999999999998, 'Carbohydrates(g)': 126.3, 'Fiber(g)': 6.0, 'Protein(g)': 26.099999999999998, 'Sodium(g)': 0.5}
# {'Energy(kcal)': 1740.0, 'Fat(g)': 58.199999999999996, 'Carbohydrates(g)': 252.6, 'Fiber(g)': 12.0, 'Protein(g)': 52.199999999999996, 'Sodium(g)': 1.0}

# %%
# df for final results joining
results_all = pd.DataFrame()

# %% [markdown]
# ### McD & SB menus

# %%
# SB and McD combined and processed menu: 
menu_df = pd.read_csv ('combined_processed.csv', sep=',', encoding = 'koi8-r')
menu_df.head()
# Out:
#   McD/SB Category    Kind               Item  Energy(kcal)  Fat(g)  \
# 0     SB     food  Bakery       Chonga Bagel           300     5.0
# 1     SB     food  Bakery       8-Grain Roll           380     6.0
# 2     SB     food  Bakery   Almond Croissant           410    22.0
# 3     SB     food  Bakery   Banana Nut Bread           420    22.0
# 4     SB     food  Bakery  Birthday Cake Pop           170     9.0
#
#    Carbohydrates(g)  Fiber(g)  Protein(g)  Sodium(g)
# 0                50       3.0          12       0.53
# 1                70       7.0          10       0.43
# 2                45       3.0          10       0.39
# 3                52       2.0           6       0.32
# 4                23       0.0           1       0.11

# %%
# normalizing whole dataset for meal_norm --> new features:
for item in menu_df[['Energy(kcal)','Fat(g)', 'Carbohydrates(g)','Fiber(g)', 'Protein(g)', 'Sodium(g)']]:
    for key in meal_norm:
        if key == item:
            menu_df['n_'+item] = menu_df[item] / float (meal_norm[key])

menu_df.head()
# menu_df.to_csv('menu_normalized.csv')
# Out:
#   McD/SB Category    Kind               Item  Energy(kcal)  Fat(g)  \
# 0     SB     food  Bakery       Chonga Bagel           300     5.0
# 1     SB     food  Bakery       8-Grain Roll           380     6.0
# 2     SB     food  Bakery   Almond Croissant           410    22.0
# 3     SB     food  Bakery   Banana Nut Bread           420    22.0
# 4     SB     food  Bakery  Birthday Cake Pop           170     9.0
#
#    Carbohydrates(g)  Fiber(g)  Protein(g)  Sodium(g)  n_Energy(kcal)  \
# 0                50       3.0          12       0.53        0.344828
# 1                70       7.0          10       0.43        0.436782
# 2                45       3.0          10       0.39        0.471264
# 3                52       2.0           6       0.32        0.482759
# 4                23       0.0           1       0.11        0.195402
#
#    n_Fat(g)  n_Carbohydrates(g)  n_Fiber(g)  n_Protein(g)  n_Sodium(g)
# 0  0.171821            0.395883    0.500000      0.459770         1.06
# 1  0.206186            0.554236    1.166667      0.383142         0.86
# 2  0.756014            0.356295    0.500000      0.383142         0.78
# 3  0.756014            0.411718    0.333333      0.229885         0.64
# 4  0.309278            0.182106    0.000000      0.038314         0.22

# %% [markdown]
# ### Preserve SB menu

# %%
# selecting SB part of whole df by index:
SB_menu = menu_df.iloc[0:217]

#  drop cols with 'old' (original, non-normalized) values:
SB_menu.drop(['McD/SB', 'Energy(kcal)', 
               'Fat(g)', 'Carbohydrates(g)', 
               'Fiber(g)', 'Protein(g)', 'Sodium(g)'], axis=1, inplace=True)

SB_menu.reset_index(drop=True, inplace=True)
SB_menu.head ()
# Out:
# C:\Users\u1\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#   Category    Kind               Item  n_Energy(kcal)  n_Fat(g)  \
# 0     food  Bakery       Chonga Bagel        0.344828  0.171821
# 1     food  Bakery       8-Grain Roll        0.436782  0.206186
# 2     food  Bakery   Almond Croissant        0.471264  0.756014
# 3     food  Bakery   Banana Nut Bread        0.482759  0.756014
# 4     food  Bakery  Birthday Cake Pop        0.195402  0.309278
#
#    n_Carbohydrates(g)  n_Fiber(g)  n_Protein(g)  n_Sodium(g)
# 0            0.395883    0.500000      0.459770         1.06
# 1            0.554236    1.166667      0.383142         0.86
# 2            0.356295    0.500000      0.383142         0.78
# 3            0.411718    0.333333      0.229885         0.64
# 4            0.182106    0.000000      0.038314         0.22

# %%
# all SB item groups
SB_menu['Kind'].unique()
# Out:
# array(['Bakery', 'Salads', 'Cold Sandwiches', 'Protein Boxes & Bowls',
#        'Warm Sandwiches', 'Yogurt & Custard', 'Soups', 'Hot Breakfast',
#        'Biscotti & Cookies', 'Chocolates & Candy', 'Fruit & Nuts',
#        'Popcorn & Chips', 'Meat & Cheese', 'Snack Bars', 'Cold Drinks',
#        'Hot Drinks'], dtype=object)

# %%
# for SB menu-based let's assume menus following kinds. The groups could be
# combined to obtain 2 and 3-item meal. Lists of item groups:
SB_first = ['Soups', 'Salads', 'Protein Boxes & Bowls', 'Hot Breakfast']
SB_second = ['Bakery', 'Cold Sandwiches', 'Warm Sandwiches']
SB_desserts = ['Chocolates & Candy', 'Fruit & Nuts', 'Biscotti & Cookies', 'Yogurt & Custard']
SB_snacks = ['Meat & Cheese', 'Snack Bars', 'Fruit & Nuts', 'Popcorn & Chips']
SB_drinks = ['Cold Drinks', 'Hot Drinks']

# 3-item 'solid breakfast':
SB_b = [SB_first, SB_second, SB_drinks] 

# 2-item 'light breakfast':
SB_light_b = [SB_first, SB_drinks]

# 3-item 'solid dinner':
SB_d = [SB_second, SB_desserts, SB_drinks]

# 2-item 'light dinner':
SB_light_d = [SB_second, SB_drinks]

# 2-item 'snack breakfast/dinner':
SB_snack = [SB_snacks, SB_drinks]

# all non-repeated element-wise combinatorial trick with Itertools 'product' function
SB_current = list(product(*SB_snack))

# %%
# see what (and how many) combinations in certain meal:
SB_current
len (SB_current)
# Out:
# 8

# %% [markdown]
# Current list name (<b>'SB_snack'</b> as example) should be passed to <b>'SB_current'</b> variable for unpacking and processing:

# %%
# Full set of combinations for 2-item breakfast / 3-item dinner formats from above catrgories
# I know... Not full-automated and bad code... 

# 3-item or 2-item meals (manual switch):

# k1, k2, k3 = [], [], []
k1, k2 = [], []

def meal_maker (row, args=SB_current[0]): # iterated manually from 0 to len(McD_current)-1
    
    '''function for making lists of all items that contain in respective item groups in 
    'SB_current' format 3-item or 2-item --> 3 (or 2) lists of items'''
    
    # Well, not so elegant code... But slices cause kernel death

    if args[0] in row[1]:
        k1.append (list ([row[2], row[3], row[4], row[5], row[6], row[7], row[8]]))
    if args[1] in row[1]:
        k2.append (list ([row[2], row[3], row[4], row[5], row[6], row[7], row[8]]))
#     if args[2] in row[1]:
#         k3.append (list ([row[2], row[3], row[4], row[5], row[6], row[7], row[8]]))
    
    return k1,k2  #,k3

SB_menu.apply (meal_maker, axis=1)

# make all non-repeated element-wise combinations of items (by default of 3-item meal)
# and create with the results
arrs = [k1,k2] # ,k3
combinator = list(product(*arrs))
df_combi = pd.DataFrame (combinator, columns = ['first', 'second']) # , 'third'
df_combi.head()
# Out:
#                                                first  \
# 0  [Creminelli Sopressata Monterey Jack Snack Tra...
# 1  [Creminelli Sopressata Monterey Jack Snack Tra...
# 2  [Creminelli Sopressata Monterey Jack Snack Tra...
# 3  [Creminelli Sopressata Monterey Jack Snack Tra...
# 4  [Creminelli Sopressata Monterey Jack Snack Tra...
#
#                                               second
# 0  [Cool Lime Starbucks Refreshers Beverage, 0.05...
# 1  [Strawberry Acai Starbucks Refreshers Beverage...
# 2  [Vegan Superberry Aeae, 0.39080459770114945, 0...
# 3  [Very Berry Hibiscus Starbucks Refreshers Beve...
# 4  [Evolution FreshOrganic Ginger Limeade, 0.1264...

# %%
# Add to all these combinations the metrics of total caloric and nutrition values 
# (Yes, it could be designed with more pythonic and elegant code...)

'''df row-applied functions sums of each value (calories, fat... e t.c.) for each 
    item in meal combination across all generated meal combinations.'''

# ENERGY total of certain meal combination:
def e_sum (row):
    e_sum = row[0][1] + row[1][1] # + row[2][1]
    return e_sum

# FAT total of certain meal combination:
def f_sum (row):   
    f_sum = row[0][2] + row[1][2] # + row[2][2]
    return f_sum

# CARBOHYDRATES total of certain meal combination:
def c_sum (row):       
    c_sum = row[0][3] + row[1][3] # + row[2][3]        
    return c_sum

# FIBER total of certain meal combination:
def fi_sum (row):
    fi_sum = row[0][4] + row[1][4] # + row[2][4]
    return fi_sum

# PROTEIN total of certain meal combination:
def p_sum (row): 
    p_sum = row[0][5] + row[1][5] # + row[2][5]
    return p_sum

# SODIUM total of certain meal combination:
def s_sum (row):
    s_sum = row[0][6] + row[1][6] # + row[2][6]
    return s_sum

df_combi['Energy'] = df_combi.apply (e_sum, axis=1)
df_combi['Fat'] = df_combi.apply (f_sum, axis=1)
df_combi['Carbohydrates'] = df_combi.apply (c_sum, axis=1)
df_combi['Fiber'] = df_combi.apply (fi_sum, axis=1)
df_combi['Protein'] = df_combi.apply (p_sum, axis=1)
df_combi['Sodium'] = df_combi.apply (s_sum, axis=1)

# full item combinations in terms of total normalized caloric and nutrition values.
# Add cols for whole group name and group combination names:
df_combi.insert(0, 'McD/SB', 'SB_snack')
df_combi.insert(1, 'Kind', str(SB_current[0]))

# %%
# Finally mean and std for all totals as metrics wether certain item combination
# is well-balanced: MEAN ≈ 1 --> average value across 6 values ≈ norm, 
# STDEV ≈ 0 --> each value of all 6 values ≈ norm 
df_combi['MEAN'] = df_combi.mean(axis=1)
df_combi['STDEV'] = df_combi.iloc[:,:-1].std(axis=1)
df_combi
# Out:
#        McD/SB                              Kind  \
# 0    SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 1    SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 2    SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 3    SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 4    SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 5    SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 6    SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 7    SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 8    SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 9    SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 10   SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 11   SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 12   SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 13   SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 14   SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 15   SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 16   SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 17   SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 18   SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 19   SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 20   SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 21   SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 22   SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 23   SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 24   SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 25   SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 26   SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 27   SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 28   SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 29   SB_snack  ('Meat & Cheese', 'Cold Drinks')
# ..        ...                               ...
# 348  SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 349  SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 350  SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 351  SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 352  SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 353  SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 354  SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 355  SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 356  SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 357  SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 358  SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 359  SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 360  SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 361  SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 362  SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 363  SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 364  SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 365  SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 366  SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 367  SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 368  SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 369  SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 370  SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 371  SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 372  SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 373  SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 374  SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 375  SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 376  SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 377  SB_snack  ('Meat & Cheese', 'Cold Drinks')
#
#                                                  first  \
# 0    [Creminelli Sopressata Monterey Jack Snack Tra...
# 1    [Creminelli Sopressata Monterey Jack Snack Tra...
# 2    [Creminelli Sopressata Monterey Jack Snack Tra...
# 3    [Creminelli Sopressata Monterey Jack Snack Tra...
# 4    [Creminelli Sopressata Monterey Jack Snack Tra...
# 5    [Creminelli Sopressata Monterey Jack Snack Tra...
# 6    [Creminelli Sopressata Monterey Jack Snack Tra...
# 7    [Creminelli Sopressata Monterey Jack Snack Tra...
# 8    [Creminelli Sopressata Monterey Jack Snack Tra...
# 9    [Creminelli Sopressata Monterey Jack Snack Tra...
# 10   [Creminelli Sopressata Monterey Jack Snack Tra...
# 11   [Creminelli Sopressata Monterey Jack Snack Tra...
# 12   [Creminelli Sopressata Monterey Jack Snack Tra...
# 13   [Creminelli Sopressata Monterey Jack Snack Tra...
# 14   [Creminelli Sopressata Monterey Jack Snack Tra...
# 15   [Creminelli Sopressata Monterey Jack Snack Tra...
# 16   [Creminelli Sopressata Monterey Jack Snack Tra...
# 17   [Creminelli Sopressata Monterey Jack Snack Tra...
# 18   [Creminelli Sopressata Monterey Jack Snack Tra...
# 19   [Creminelli Sopressata Monterey Jack Snack Tra...
# 20   [Creminelli Sopressata Monterey Jack Snack Tra...
# 21   [Creminelli Sopressata Monterey Jack Snack Tra...
# 22   [Creminelli Sopressata Monterey Jack Snack Tra...
# 23   [Creminelli Sopressata Monterey Jack Snack Tra...
# 24   [Creminelli Sopressata Monterey Jack Snack Tra...
# 25   [Creminelli Sopressata Monterey Jack Snack Tra...
# 26   [Creminelli Sopressata Monterey Jack Snack Tra...
# 27   [Creminelli Sopressata Monterey Jack Snack Tra...
# 28   [Creminelli Sopressata Monterey Jack Snack Tra...
# 29   [Creminelli Sopressata Monterey Jack Snack Tra...
# ..                                                 ...
# 348  [String Cheese, 0.09195402298850575, 0.2061855...
# 349  [String Cheese, 0.09195402298850575, 0.2061855...
# 350  [String Cheese, 0.09195402298850575, 0.2061855...
# 351  [String Cheese, 0.09195402298850575, 0.2061855...
# 352  [String Cheese, 0.09195402298850575, 0.2061855...
# 353  [String Cheese, 0.09195402298850575, 0.2061855...
# 354  [String Cheese, 0.09195402298850575, 0.2061855...
# 355  [String Cheese, 0.09195402298850575, 0.2061855...
# 356  [String Cheese, 0.09195402298850575, 0.2061855...
# 357  [String Cheese, 0.09195402298850575, 0.2061855...
# 358  [String Cheese, 0.09195402298850575, 0.2061855...
# 359  [String Cheese, 0.09195402298850575, 0.2061855...
# 360  [String Cheese, 0.09195402298850575, 0.2061855...
# 361  [String Cheese, 0.09195402298850575, 0.2061855...
# 362  [String Cheese, 0.09195402298850575, 0.2061855...
# 363  [String Cheese, 0.09195402298850575, 0.2061855...
# 364  [String Cheese, 0.09195402298850575, 0.2061855...
# 365  [String Cheese, 0.09195402298850575, 0.2061855...
# 366  [String Cheese, 0.09195402298850575, 0.2061855...
# 367  [String Cheese, 0.09195402298850575, 0.2061855...
# 368  [String Cheese, 0.09195402298850575, 0.2061855...
# 369  [String Cheese, 0.09195402298850575, 0.2061855...
# 370  [String Cheese, 0.09195402298850575, 0.2061855...
# 371  [String Cheese, 0.09195402298850575, 0.2061855...
# 372  [String Cheese, 0.09195402298850575, 0.2061855...
# 373  [String Cheese, 0.09195402298850575, 0.2061855...
# 374  [String Cheese, 0.09195402298850575, 0.2061855...
# 375  [String Cheese, 0.09195402298850575, 0.2061855...
# 376  [String Cheese, 0.09195402298850575, 0.2061855...
# 377  [String Cheese, 0.09195402298850575, 0.2061855...
#
#                                                 second    Energy       Fat  \
# 0    [Cool Lime Starbucks Refreshers Beverage, 0.05...  0.304598  0.584192
# 1    [Strawberry Acai Starbucks Refreshers Beverage...  0.344828  0.584192
# 2    [Vegan Superberry Aeae, 0.39080459770114945, 0...  0.643678  0.996564
# 3    [Very Berry Hibiscus Starbucks Refreshers Beve...  0.321839  0.584192
# 4    [Evolution FreshOrganic Ginger Limeade, 0.1264...  0.379310  0.584192
# 5    [Iced Espresso Classics - Vanilla Latte, 0.149...  0.402299  0.670103
# 6    [Iced Espresso Classics - Caffe Mocha, 0.16091...  0.413793  0.670103
# 7    [Iced Espresso Classics - Caramel Macchiato, 0...  0.402299  0.670103
# 8    [Shaken Sweet Tea, 0.09195402298850575, 0.0, 0...  0.344828  0.584192
# 9    [Tazoп╠ Bottled Berry Blossom White, 0.0689655...  0.321839  0.584192
# 10   [Tazoп╠ Bottled Black Mango, 0.172413793103448...  0.425287  0.584192
# 11   [Tazoп╠ Bottled Black with Lemon, 0.1609195402...  0.413793  0.584192
# 12   [Tazoп╠ Bottled Brambleberry, 0.16091954022988...  0.413793  0.584192
# 13   [Tazoп╠ Bottled Giant Peach, 0.172413793103448...  0.425287  0.584192
# 14   [Tazoп╠ Bottled Iced Passion, 0.08045977011494...  0.333333  0.584192
# 15   [Tazoп╠ Bottled Lemon Ginger, 0.13793103448275...  0.390805  0.584192
# 16   [Tazoп╠ Bottled Organic Black Lemonade, 0.1609...  0.413793  0.584192
# 17   [Tazoп╠ Bottled Organic Iced Black Tea, 0.0689...  0.321839  0.584192
# 18   [Tazoп╠ Bottled Organic Iced Green Tea, 0.1379...  0.390805  0.584192
# 19   [Tazoп╠ Bottled Plum Pomegranate, 0.1609195402...  0.413793  0.584192
# 20   [Tazoп╠ Bottled Tazoberry, 0.1724137931034483,...  0.425287  0.584192
# 21   [Tazoп╠ Bottled White Cranberry, 0.16091954022...  0.413793  0.584192
# 22   [Teavanaп╠ Shaken Iced Black Tea, 0.0344827586...  0.287356  0.584192
# 23   [Teavanaп╠ Shaken Iced Black Tea Lemonade, 0.0...  0.333333  0.584192
# 24   [Teavanaп╠ Shaken Iced Green Tea, 0.0344827586...  0.287356  0.584192
# 25   [Teavanaп╠ Shaken Iced Green Tea Lemonade, 0.0...  0.333333  0.584192
# 26   [Teavanaп╠ Shaken Iced Passion Tango Tea, 0.03...  0.287356  0.584192
# 27   [Teavanaп╠ Shaken Iced Passion Tango Tea Lemon...  0.356322  0.584192
# 28   [Teavanaп╠ Shaken Iced Peach Green Tea, 0.0689...  0.321839  0.584192
# 29   [Iced Espresso Classics - Vanilla Latte, 0.149...  0.402299  0.670103
# ..                                                 ...       ...       ...
# 348  [Starbucks RefreshersStrawberry Lemonade, 0.10...  0.195402  0.206186
# 349  [Starbucks Doubleshot Protein Dark Chocolate, ...  0.333333  0.292096
# 350  [Starbucks Doubleshot Protein Vanilla, 0.22988...  0.321839  0.292096
# 351  [Starbucks Iced Coffee Caramel, 0.068965517241...  0.160920  0.206186
# 352  [Starbucks Iced Coffee Light Sweetened, 0.0574...  0.149425  0.206186
# 353  [Starbucks Iced Coffee Unsweetened, 0.01149425...  0.103448  0.206186
# 354  [Cold Brew with Cold Foam, 0.04022988505747126...  0.132184  0.206186
# 355  [Cold Brew with Salted Cream Cold Foam, 0.2643...  0.356322  0.687285
# 356  [Starbucks Cold Brew Coffee, 0.005747126436781...  0.097701  0.206186
# 357  [Nitro Cold Brew, 0.005747126436781609, 0.0, 0...  0.097701  0.206186
# 358  [Nitro Cold Brew with Cascara Cold Foam, 0.091...  0.183908  0.206186
# 359  [Nitro Cold Brew with Sweet Cream, 0.080459770...  0.172414  0.378007
# 360  [Pumpkin Cream Cold Brew, 0.28735632183908044,...  0.379310  0.618557
# 361  [Vanilla Sweet Cream Cold Brew, 0.126436781609...  0.218391  0.412371
# 362  [Coconutmilk Mocha Macchiato, 0.28735632183908...  0.379310  0.515464
# 363  [Flat White, 0.20689655172413793, 0.2405498281...  0.298851  0.446735
# 364  [Iced Caffe Latte, 0.14942528735632185, 0.1546...  0.241379  0.360825
# 365  [Iced Caffe Mocha, 0.26436781609195403, 0.2061...  0.356322  0.412371
# 366  [Iced Caramel Macchiato, 0.28735632183908044, ...  0.379310  0.446735
# 367  [Iced Cinnamon Dolce Latte, 0.2298850574712643...  0.321839  0.343643
# 368  [Iced Coconutmilk Mocha Macchiato, 0.298850574...  0.390805  0.515464
# 369  [Iced Vanilla Latte, 0.21839080459770116, 0.13...  0.310345  0.343643
# 370  [Iced White Chocolate Mocha, 0.344827586206896...  0.436782  0.481100
# 371  [Vanilla Latte, 0.28735632183908044, 0.2061855...  0.379310  0.412371
# 372  [Cinnamon Dolce Frappuccino Blended Coffee, 0....  0.494253  0.360825
# 373  [Coffee Light Frappuccino Blended Coffee, 0.12...  0.218391  0.206186
# 374  [Mocha Frappuccino Blended Coffee, 0.321839080...  0.413793  0.292096
# 375  [Mocha Light Frappuccino Blended Coffee, 0.160...  0.252874  0.223368
# 376  [Chocolate Smoothie, 0.367816091954023, 0.1718...  0.459770  0.378007
# 377  [Strawberry Smoothie, 0.3448275862068966, 0.06...  0.436782  0.274914
#
#      Carbohydrates     Fiber   Protein  Sodium      MEAN     STDEV
# 0         0.087094  0.000000  0.574713    1.46  0.501766  0.527811
# 1         0.142518  0.166667  0.574713    1.46  0.545486  0.486793
# 2         0.435471  1.333333  0.804598    1.72  0.988941  0.471726
# 3         0.110847  0.166667  0.574713    1.46  0.536376  0.494090
# 4         0.221694  0.000000  0.574713    1.45  0.534985  0.499969
# 5         0.166271  0.000000  0.766284    1.57  0.595826  0.558671
# 6         0.182106  0.000000  0.766284    1.62  0.608714  0.573030
# 7         0.166271  0.000000  0.766284    1.57  0.595826  0.558671
# 8         0.150435  0.000000  0.574713    1.46  0.519028  0.515436
# 9         0.118765  0.000000  0.574713    1.46  0.509918  0.521682
# 10        0.300871  0.000000  0.574713    1.47  0.559177  0.495539
# 11        0.277118  0.000000  0.574713    1.46  0.551636  0.495052
# 12        0.277118  0.000000  0.574713    1.47  0.553303  0.498725
# 13        0.292953  0.000000  0.574713    1.47  0.557858  0.496374
# 14        0.134600  0.000000  0.574713    1.46  0.514473  0.518519
# 15        0.245447  0.000000  0.574713    1.46  0.542526  0.500028
# 16        0.277118  0.000000  0.574713    1.46  0.551636  0.495052
# 17        0.118765  0.000000  0.574713    1.46  0.509918  0.521682
# 18        0.245447  0.000000  0.574713    1.46  0.542526  0.500028
# 19        0.277118  0.000000  0.574713    1.46  0.551636  0.495052
# 20        0.300871  0.000000  0.574713    1.47  0.559177  0.495539
# 21        0.277118  0.000000  0.574713    1.46  0.551636  0.495052
# 22        0.063341  0.000000  0.574713    1.45  0.493267  0.529299
# 23        0.134600  0.000000  0.574713    1.44  0.511140  0.511238
# 24        0.063341  0.000000  0.574713    1.45  0.493267  0.529299
# 25        0.134600  0.000000  0.574713    1.45  0.512806  0.514875
# 26        0.063341  0.000000  0.574713    1.45  0.493267  0.529299
# 27        0.190024  0.000000  0.574713    1.44  0.524208  0.501893
# 28        0.118765  0.000000  0.574713    1.44  0.506585  0.514411
# 29        0.166271  0.000000  0.766284    1.57  0.595826  0.558671
# ..             ...       ...       ...     ...       ...       ...
# 348       0.221694  0.000000  0.268199    0.40  0.215247  0.129450
# 349       0.269200  0.333333  1.034483    0.63  0.482074  0.300896
# 350       0.277118  0.333333  1.034483    0.64  0.483145  0.301989
# 351       0.110847  0.000000  0.306513    0.40  0.197411  0.141999
# 352       0.095012  0.000000  0.306513    0.40  0.192856  0.144677
# 353       0.023753  0.000000  0.306513    0.40  0.173317  0.159685
# 354       0.063341  0.000000  0.344828    0.46  0.201090  0.174288
# 355       0.190024  0.000000  0.344828    1.06  0.439743  0.378866
# 356       0.007918  0.000000  0.268199    0.43  0.168334  0.166694
# 357       0.007918  0.000000  0.268199    0.42  0.166667  0.163575
# 358       0.150435  0.000000  0.344828    0.46  0.224226  0.159880
# 359       0.047506  0.000000  0.306513    0.44  0.224073  0.179538
# 360       0.253365  0.000000  0.383142    0.51  0.357396  0.215030
# 361       0.118765  0.000000  0.306513    0.45  0.251007  0.173363
# 362       0.261283  0.000000  0.727969    0.76  0.440671  0.289911
# 363       0.150435  0.000000  0.727969    0.72  0.390665  0.298040
# 364       0.110847  0.000000  0.574713    0.63  0.319627  0.250986
# 365       0.292953  0.666667  0.613027    0.58  0.486890  0.153044
# 366       0.300871  0.000000  0.651341    0.70  0.413043  0.254790
# 367       0.277118  0.000000  0.536398    0.59  0.344833  0.210157
# 368       0.277118  0.000000  0.689655    0.76  0.438840  0.280344
# 369       0.245447  0.000000  0.536398    0.60  0.339306  0.215222
# 370       0.380048  0.000000  0.651341    0.78  0.454878  0.267518
# 371       0.300871  0.000000  0.727969    0.70  0.420087  0.270389
# 372       0.514648  0.000000  0.842912    0.40  0.435440  0.272836
# 373       0.197941  0.000000  0.383142    0.80  0.300943  0.273051
# 374       0.482977  0.333333  0.421456    0.84  0.463943  0.196312
# 375       0.229612  0.166667  0.421456    0.76  0.342329  0.222003
# 376       0.427553  1.333333  1.034483    0.74  0.728858  0.386060
# 377       0.482977  1.166667  0.881226    0.66  0.650428  0.326973
#
# [378 rows x 12 columns]

# %%
# results df building
results_all = results_all.append(df_combi)
results_all.head()
# Out:
#      McD/SB                              Kind  \
# 0  SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 1  SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 2  SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 3  SB_snack  ('Meat & Cheese', 'Cold Drinks')
# 4  SB_snack  ('Meat & Cheese', 'Cold Drinks')
#
#                                                first  \
# 0  [Creminelli Sopressata Monterey Jack Snack Tra...
# 1  [Creminelli Sopressata Monterey Jack Snack Tra...
# 2  [Creminelli Sopressata Monterey Jack Snack Tra...
# 3  [Creminelli Sopressata Monterey Jack Snack Tra...
# 4  [Creminelli Sopressata Monterey Jack Snack Tra...
#
#                                               second    Energy       Fat  \
# 0  [Cool Lime Starbucks Refreshers Beverage, 0.05...  0.304598  0.584192
# 1  [Strawberry Acai Starbucks Refreshers Beverage...  0.344828  0.584192
# 2  [Vegan Superberry Aeae, 0.39080459770114945, 0...  0.643678  0.996564
# 3  [Very Berry Hibiscus Starbucks Refreshers Beve...  0.321839  0.584192
# 4  [Evolution FreshOrganic Ginger Limeade, 0.1264...  0.379310  0.584192
#
#    Carbohydrates     Fiber   Protein  Sodium      MEAN     STDEV
# 0       0.087094  0.000000  0.574713    1.46  0.501766  0.527811
# 1       0.142518  0.166667  0.574713    1.46  0.545486  0.486793
# 2       0.435471  1.333333  0.804598    1.72  0.988941  0.471726
# 3       0.110847  0.166667  0.574713    1.46  0.536376  0.494090
# 4       0.221694  0.000000  0.574713    1.45  0.534985  0.499969

# %%
# # writing results df (when all combinations processed):
# results_all.reset_index(inplace=True, drop=True)
# results_all.to_csv('SB_sncak_results.csv', index=False)
