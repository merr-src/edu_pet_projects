# %% [markdown]
# ## Analytics in terms of B-index

# %% [markdown]
# ### 1. "Solid dinner" McD combination set

# %%
# required imports
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# list with 24 combinations of 3 items, they specified in same order 
# as B_index cols in df below --> 1-st col 'SB_solid_b_0' and so on

combi_list = []

with open ('McD_solid_d_8.txt', 'r') as f:
    for line in f:
        line = line[:-1]
        combi_list.append (line)
    f.close()

# %%
McD_solid_d_8 = pd.read_csv ('McD_solid_d_8.csv',  skiprows=1, names=combi_list , sep=(','))
McD_solid_d_8.head()
# Out:
#    ('Chiken Snacks', 'Sweets/Desserts', 'Cold Drinks')  \
# 0                                           2.296940
# 1                                           2.220737
# 2                                           2.148466
# 3                                           2.364639
# 4                                           2.661398
#
#    ('Chiken Snacks', 'Sweets/Desserts', 'Hot Drinks')  \
# 0                                           2.279324
# 1                                           2.234614
# 2                                           2.192571
# 3                                           2.361592
# 4                                           1.636407
#
#    ('Chiken Snacks', 'Sweets/Snacks', 'Cold Drinks')  \
# 0                                           1.126251
# 1                                           1.108915
# 2                                           1.089989
# 3                                           1.139321
# ...

# %%
# cols of different length!
McD_solid_d_8.describe()
# Out:
#        ('Chiken Snacks', 'Sweets/Desserts', 'Cold Drinks')  \
# count                                        7740.000000
# mean                                            1.603025
# std                                             0.777654
# min                                             0.609082
# 25%                                             1.115770
# 50%                                             1.437576
# 75%                                             1.866988
# max                                             9.778371
#
#        ('Chiken Snacks', 'Sweets/Desserts', 'Hot Drinks')  \
# count                                        4680.000000
# mean                                            1.289453
# std                                             0.425824
# min                                             0.701442
# 25%                                             1.034642
# 50%                                             1.199387
# ...

# %%
# B_index mean values for all groups
cols = pd.Index.to_list(McD_solid_d_8.columns[0:])
McD_solid_d_8[cols].mean().plot(kind = 'bar', subplots = False, width = 0.5, figsize = (8,4), grid = True)

# %%
# above cutoff:
above_cut = (McD_solid_d_8.mean() > 1.25)
above_drop_list = [col for col in above_cut]
a = above_cut.loc[above_drop_list]
above_drop = pd.Index.to_list(a.index)

# bellow cutoff:
bellow_cut = (McD_solid_d_8.mean() < 0.75)
bellow_drop_list = [col for col in bellow_cut]
b = bellow_cut.loc[bellow_drop_list]
bellow_drop = pd.Index.to_list(b.index)

# deleting columns:
McD_solid_d_8.drop (columns = above_drop, inplace=True)
McD_solid_d_best = McD_solid_d_8
McD_solid_d_best.describe()
# Out:
#        ('Chiken Snacks', 'Sweets/Snacks', 'Cold Drinks')  \
# count                                        6880.000000
# mean                                            1.011781
# std                                             0.268130
# min                                             0.477143
# 25%                                             0.819970
# 50%                                             0.964153
# 75%                                             1.179861
# max                                             2.238752
#
#        ('Chiken Snacks', 'Sweets/Snacks', 'Hot Drinks')  \
# count                                       4160.000000
# mean                                           0.893064
# std                                            0.187822
# min                                            0.531190
# 25%                                            0.750759
# 50%                                            0.873896
# ...

# %%
# vizualizing filtered df:
cols = pd.Index.to_list(McD_solid_d_best.columns[0:])
McD_solid_d_best[cols].mean().plot(kind = 'bar', subplots = False, width = 0.5, figsize = (6,4), grid = True)

# %%
McD_solid_d_best.to_csv ('McD_solid_d_best.csv')
