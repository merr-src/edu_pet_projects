# %% [markdown]
# ## Educational analytic case with McDonalds and Starbucks menu: what would be better as meals for teens?

# %% [markdown]
# [Case description] Restrictions from the task description [Restrictions, document-1 = link, document-2 = link]
#
# DONE:
# - values from norms (document-1) extracted manually --> txt --> dict. We find only 6 values: Energy(kcal), Fat(g), Carbohydrates(g), Fiber(g), Protein(g), Sodium (g), wich exist in all three datasets (document-1, McD and SB menus)
# - values from McD and SB .csv menus --> Excel --> (processing: combine, add features in cols, enrichment)
# - features added: (1) 'McD=0_SB=1': restraunt coding, (2) 'Category': food/drink, (3) 'Kind': bakery/breakfast/hot drink etc.
# - dataset enriched manually: about 60 items in 'Snacks & sweets' category were added for SB menu. Thus we have more balanced dataaset (McD/SB share).
# - discard from zeroes: dividing all mass values by 1000 (mg --> g)
# - several bug fixes in values
# - deleted items with all zeroes
# - calculate weighted norms - according the rule requirement from official document-2
# - deleting dishes with > 60% (breakfast + dinner) of day norm caloric or nutrition values (for instance, 1880 kcal (40 pieces of chicken McNuggets)
#
# PLAN:
# - include potential allergics - new feature?
# - add the data on serving sizes
# - search for nutrition indices or calculate integrated nutrition index (may be Carb:Fat:Prot matching those in norms?) and visualize it
# - develop the decision making algorithm for combining potential breakfast and dinner sets
# - test the algorithm, corrections
# - extract the results, preference for hot dishes and moderate-sugared drinks

# %%
# required imports
import pandas as pd
import numpy as np
from itertools import product, combinations
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Official norms

# %%
# Dict with actual norms (from official document-1)
norms = {}

f = open ('actual_norms.txt')

for line in f:
    line = line.strip().split(',')
    norms[line[0]] = line[1]
    
del norms['Item']
norms
# Out:
# {'Energy(kcal)': '2900',
#  'Fat(g)': '97',
#  'Carbohydrates(g)': '421',
#  'Fiber(g)': '20',
#  'Protein(g)': '87',
#  'Sodium(g)': '1.3'}

# %%
# (From official document-2): 
# -breakfast + dinner = 20-25% + 30-35% daily energy value respectively --> 
# 25% and 35% (max due to sports competitions)
# -breakfast + dinner = 55-60% total daily nutrients value --> 
# 25% and 35% (max due to sports competitions)
# (only breakfast and dinner mentioned in the task)
# Let's assume that breakfast / dinner share are equal --> 
# meal_norm (30% and 30% respectively)

# calculating weighted norms:

meal_norm = {}

for key, value in norms.items():
    meal_norm[key] = float(value)*0.3
    
# sum_norm dict for data filtering (del items which contain greater values):   
sum_norm = {key:float(value)*0.6 for key, value in norms.items()}
    
print (meal_norm)
print (sum_norm)
# Out:
# {'Energy(kcal)': 870.0, 'Fat(g)': 29.099999999999998, 'Carbohydrates(g)': 126.3, 'Fiber(g)': 6.0, 'Protein(g)': 26.099999999999998, 'Sodium(g)': 0.39}
# {'Energy(kcal)': 1740.0, 'Fat(g)': 58.199999999999996, 'Carbohydrates(g)': 252.6, 'Fiber(g)': 12.0, 'Protein(g)': 52.199999999999996, 'Sodium(g)': 0.78}

# %% [markdown]
# ### McD & SB menus

# %%
# Starbucks (SB) and McDonalds (McD) combined menu in single df: 
menu_df = pd.read_csv ('combined_menu_300919.csv', sep=';', encoding = 'koi8-r')
menu_df.head()
# Out:
#    McD=0_SB=1 Category    Kind               Item  Energy(kcal)  Fat(g)  \
# 0           1     food  Bakery       Chonga Bagel           300     5.0
# 1           1     food  Bakery       8-Grain Roll           380     6.0
# 2           1     food  Bakery   Almond Croissant           410    22.0
# 3           1     food  Bakery   Banana Nut Bread           420    22.0
# 4           1     food  Bakery  Birthday Cake Pop           170     9.0
#
#    Carbohydrates(g)  Fiber(g)  Protein(g)  Sodium(g)
# 0                50       3.0          12       0.53
# 1                70       7.0          10       0.43
# 2                45       3.0          10       0.39
# 3                52       2.0           6       0.32
# 4                23       0.0           1       0.11

# %%
# checking data gaps - it's OK
menu_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
# McD=0_SB=1          500 non-null int64
# Category            500 non-null object
# Kind                500 non-null object
# Item                500 non-null object
# Energy(kcal)        500 non-null int64
# Fat(g)              500 non-null float64
# Carbohydrates(g)    500 non-null int64
# Fiber(g)            500 non-null float64
# Protein(g)          500 non-null int64
# Sodium(g)           500 non-null float64
# dtypes: float64(3), int64(4), object(3)
# memory usage: 39.1+ KB

# %% [markdown]
# ### Clean the data

# %%
# any all-zero items to delete?
del_list = []
def find_zeroes (row):
    '''the function recieve row of a df and process it: if all quantitative fields 
    are zeroes in the row, the row included in list for deleting'''
    if row[4:].sum() == 0:
#         print (row)
        del_list.append (row[3])
        
menu_df.apply (find_zeroes, axis = 1)
menu_df = menu_df.loc[~menu_df['Item'].isin(del_list)]
len (menu_df) # 7 values deleted
# Out:
# 493

# %%
# filtering: del items which contain values greater than weighted norm in sum_norm dict:

menu_df[menu_df['Energy(kcal)']>=sum_norm['Energy(kcal)']]
# only 1 item exceeds sum_norms (1740 kcal)
# Out:
#      McD=0_SB=1 Category                Kind                          Item  \
# 322           0     food  Sandwiches/Burgers  Chicken McNuggets (40 piece)
#
#      Energy(kcal)  Fat(g)  Carbohydrates(g)  Fiber(g)  Protein(g)  Sodium(g)
# 322          1880   118.0               118       6.0          87        3.6

# %%
menu_df[menu_df['Fat(g)']>=sum_norm['Fat(g)']]
# 3 items exceed sum_norms (58.2 g)
# Out:
#      McD=0_SB=1 Category                Kind  \
# 272           0     food       Hot Breakfast
# 321           0     food  Sandwiches/Burgers
# 322           0     food  Sandwiches/Burgers
#
#                                             Item  Energy(kcal)  Fat(g)  \
# 272  Big Breakfast with Hotcakes (Large Biscuit)          1150    60.0
# 321                 Chicken McNuggets (20 piece)           940    59.0
# 322                 Chicken McNuggets (40 piece)          1880   118.0
#
#      Carbohydrates(g)  Fiber(g)  Protein(g)  Sodium(g)
# 272               116       7.0          36       2.26
# 321                59       3.0          44       1.80
# 322               118       6.0          87       3.60

# %%
menu_df[menu_df['Carbohydrates(g)']>=sum_norm['Carbohydrates(g)']]
# no items exceed sum_norms
# Out:
# Empty DataFrame
# Columns: [McD=0_SB=1, Category, Kind, Item, Energy(kcal), Fat(g), Carbohydrates(g), Fiber(g), Protein(g), Sodium(g)]
# Index: []

# %%
menu_df[menu_df['Fiber(g)']>=sum_norm['Fiber(g)']]
# 2 items exceed sum_norms (12.0 g)
# Out:
#      McD=0_SB=1 Category                   Kind  \
# 56            1     food  Protein Boxes & Bowls
# 114           1     food           Fruit & Nuts
#
#                                                  Item  Energy(kcal)  Fat(g)  \
# 56   Lentils & Vegetable Protein Bowl with Brown Rice           650    29.0
# 114                                 Bare Fruit Medley           130     0.0
#
#      Carbohydrates(g)  Fiber(g)  Protein(g)  Sodium(g)
# 56                 80      21.0          23       0.67
# 114                31      24.0           1       0.00

# %%
menu_df[menu_df['Protein(g)']>=sum_norm['Protein(g)']]
# only 1 item exceeds sum_norms (52.2 g)
# Out:
#      McD=0_SB=1 Category                Kind                          Item  \
# 322           0     food  Sandwiches/Burgers  Chicken McNuggets (40 piece)
#
#      Energy(kcal)  Fat(g)  Carbohydrates(g)  Fiber(g)  Protein(g)  Sodium(g)
# 322          1880   118.0               118       6.0          87        3.6

# %%
menu_df[menu_df['Sodium(g)']>=sum_norm['Sodium(g)']]
# Wow! 104 items exceed sum_norms (0.78 g)
# Out:
#      McD=0_SB=1 Category                   Kind  \
# 36            1     food        Cold Sandwiches
# 37            1     food        Cold Sandwiches
# 38            1     food  Protein Boxes & Bowls
# 40            1     food        Warm Sandwiches
# 41            1     food        Warm Sandwiches
# 43            1     food        Cold Sandwiches
# 44            1     food        Warm Sandwiches
# 45            1     food        Warm Sandwiches
# 46            1     food        Warm Sandwiches
# 48            1     food        Warm Sandwiches
# 49            1     food                 Salads
# 51            1     food  Protein Boxes & Bowls
# 52            1     food  Protein Boxes & Bowls
# 53            1     food  Protein Boxes & Bowls
# 58            1     food  Protein Boxes & Bowls
# 61            1     food          Hot Breakfast
# 62            1     food          Hot Breakfast
# 64            1     food          Hot Breakfast
# 68            1     food          Hot Breakfast
# 69            1     food          Hot Breakfast
# 70            1     food          Hot Breakfast
# 75            1     food          Hot Breakfast
# 76            1     food          Hot Breakfast
# 77            1     food        Warm Sandwiches
# 78            1     food        Warm Sandwiches
# 79            1     food        Warm Sandwiches
# 80            1     food        Warm Sandwiches
# 81            1     food        Warm Sandwiches
# 83            1     food        Warm Sandwiches
# 242           0     food          Hot Breakfast
# ..          ...      ...                    ...
# 295           0     food     Sandwiches/Burgers
# 296           0     food     Sandwiches/Burgers
# 297           0     food     Sandwiches/Burgers
# 298           0     food     Sandwiches/Burgers
# 299           0     food     Sandwiches/Burgers
# 300           0     food     Sandwiches/Burgers
# 301           0     food     Sandwiches/Burgers
# 302           0     food     Sandwiches/Burgers
# 303           0     food     Sandwiches/Burgers
# 304           0     food     Sandwiches/Burgers
# 305           0     food     Sandwiches/Burgers
# 306           0     food     Sandwiches/Burgers
# 307           0     food     Sandwiches/Burgers
# 308           0     food     Sandwiches/Burgers
# 309           0     food     Sandwiches/Burgers
# 310           0     food     Sandwiches/Burgers
# 311           0     food     Sandwiches/Burgers
# 312           0     food     Sandwiches/Burgers
# 313           0     food     Sandwiches/Burgers
# 314           0     food     Sandwiches/Burgers
# 315           0     food     Sandwiches/Burgers
# 316           0     food     Sandwiches/Burgers
# 317           0     food     Sandwiches/Burgers
# 320           0     food     Sandwiches/Burgers
# 321           0     food     Sandwiches/Burgers
# 322           0     food     Sandwiches/Burgers
# 314  Premium McWrap Southwest Chicken (Crispy Chicken)           670    33.0
# 315  Premium McWrap Southwest Chicken (Grilled Chic...           520    20.0
# 316  Premium McWrap Chicken Sweet Chili (Crispy Chi...           540    23.0
# 317  Premium McWrap Chicken Sweet Chili (Grilled Ch...           380    10.0
# 320                       Chicken McNuggets (10 piece)           470    30.0
# 321                       Chicken McNuggets (20 piece)           940    59.0
# 322                       Chicken McNuggets (40 piece)          1880   118.0
# 325      Premium Bacon Ranch Salad with Crispy Chicken           380    21.0
# 328        Premium Southwest Salad with Crispy Chicken           450    22.0
# 330           Chipotle BBQ Snack Wrap (Crispy Chicken)           340    15.0
# 334                  Ranch Snack Wrap (Crispy Chicken)           360    20.0
#
#      Carbohydrates(g)  Fiber(g)  Protein(g)  Sodium(g)
# 36                 61       5.0          24       0.94
# 37                 55       4.0          22       1.05
# 38                 29       4.0          21       0.88
# 40                 15       4.0          21       1.14
# 41                 52       3.0          22       1.09
# 43                 47       6.0          32       0.86
# 44                 30       5.0          28       0.90
# 45                 46       4.0          18       1.19
# 46                 66       5.0          21       1.20
# 48                 50       4.0          26       1.13
# 49                 67      11.0          27       0.88
# 51                 42       9.0          27       1.03
# 52                 58       7.0          35       1.66
# 53                 45       4.0          20       1.00
# 58                 42       5.0          24       1.62
# 61                 32       1.0          18       0.78
# 62                 35       1.0          26       1.16
# 64                 40       1.0          21       1.05
# 68                 43       0.0          21       0.92
# 69                 34       1.0          18       0.88
# 70                 39       2.0          26       1.17
# 75                 36       0.0          24       0.95
# 76                 34       4.0          20       0.83
# 77                 73       7.0          21       1.30
# 78                 65       3.0          31       1.46
# 79                 58       3.0          28       0.90
# 80                 47       4.0          21       1.06
# 81                 42       0.0          25       1.25
# 83                 55       3.0          34       1.19
# 242                29       4.0          14       0.78
# ..                ...       ...         ...        ...
# 295                35       2.0          22       1.03
# 296                44       3.0          22       0.98
# 297                55       3.0          24       0.99
# 298                42       3.0          28       0.82
# 299                58       3.0          36       1.41
# 300                44       3.0          40       1.25
# 301                57       3.0          32       1.40
# 302                43       3.0          36       1.23
# 303                65       4.0          36       1.72
# 304                51       4.0          40       1.56
# 305                43       2.0          21       0.91
# 306                40       2.0          14       0.80
# 307                43       2.0          22       1.26
# 308                41       2.0          20       1.26
# 309                40       2.0          14       0.99
# 310                56       3.0          32       1.54
# 311                42       3.0          36       1.37
# 312                56       3.0          27       1.34
# 313                42       3.0          30       1.17
# 314                68       5.0          27       1.48
# 315                55       5.0          31       1.32
# 316                61       3.0          23       1.26
# 317                47       3.0          27       1.09
# 320                30       2.0          22       0.90
# 321                59       3.0          44       1.80
# 322               118       6.0          87       3.60
# 325                22       2.0          25       0.86
# 328                42       7.0          23       0.85
# 330                37       1.0          14       0.78
# 334                32       1.0          15       0.81
#
# [104 rows x 10 columns]

# %%
# Well, lets assume that salt needs increases due to sports: 1.0 g sodium threshold:
menu_df[menu_df['Sodium(g)']>=1]
# Nevertheless 73 items exceed 1.0 g
# Out:
#      McD=0_SB=1 Category                   Kind  \
# 37                 55       4.0          22       1.05
# 40                 15       4.0          21       1.14
# 41                 52       3.0          22       1.09
# 45                 46       4.0          18       1.19
# 46                 66       5.0          21       1.20
# 48                 50       4.0          26       1.13
# 51                 42       9.0          27       1.03
# 52                 58       7.0          35       1.66
# 53                 45       4.0          20       1.00
# 58                 42       5.0          24       1.62
# 62                 35       1.0          26       1.16
# 64                 40       1.0          21       1.05
# 70                 39       2.0          26       1.17
# 77                 73       7.0          21       1.30
# 78                 65       3.0          31       1.46
# 80                 47       4.0          21       1.06
# 81                 42       0.0          25       1.25
# 83                 55       3.0          34       1.19
# 246                38       2.0          19       1.30
# 247                43       3.0          19       1.41
# 248                36       2.0          20       1.30
# 249                42       3.0          20       1.42
# 250                34       2.0          11       1.08
# 251                39       3.0          11       1.19
# 252                36       2.0          18       1.17
# 253                42       3.0          18       1.28
# 254                34       2.0          18       1.18
# 255                40       3.0          18       1.29
# 256                41       2.0          17       1.18
# 257                46       3.0          17       1.29
# ..                ...       ...         ...        ...
# 271               111       6.0          36       2.15
# 272               116       7.0          36       2.26
# 273               110       6.0          35       2.17
# 274               115       7.0          35       2.29
# 283                41       3.0          30       1.10
# 284                48       3.0          37       1.44
# 285                46       3.0          37       1.18
# 287                42       3.0          48       1.28
# 290                35       2.0          24       1.04
# 291                51       4.0          39       1.47
# 293                35       2.0          27       1.11
# 295                35       2.0          22       1.03
# 299                58       3.0          36       1.41
# 300                44       3.0          40       1.25
# 301                57       3.0          32       1.40
# 302                43       3.0          36       1.23
# 303                65       4.0          36       1.72
# 304                51       4.0          40       1.56
# 307                43       2.0          22       1.26
# 308                41       2.0          20       1.26
# 310                56       3.0          32       1.54
# 311                42       3.0          36       1.37
# 312                56       3.0          27       1.34
# 313                42       3.0          30       1.17
# 314                68       5.0          27       1.48
# 315                55       5.0          31       1.32
# 316                61       3.0          23       1.26
# 317                47       3.0          27       1.09
# 321                59       3.0          44       1.80
# 322               118       6.0          87       3.60
#
# [73 rows x 10 columns]

# %%
# Let's drop out all items that exceeds the criteria:
menu_df = menu_df[menu_df['Energy(kcal)'] < sum_norm['Energy(kcal)']]
menu_df = menu_df[menu_df['Fat(g)'] < sum_norm['Fat(g)']]
menu_df = menu_df[menu_df['Fiber(g)'] < sum_norm['Fiber(g)']]
menu_df = menu_df[menu_df['Protein(g)'] < sum_norm['Protein(g)']]
menu_df = menu_df[menu_df['Sodium(g)'] < 1.0]

len (menu_df)
# Out:
# 418

# %%
# We increased the sodium sum norm 0.78 --> 1.0, i.e. +0.22. 
# In turns it increases sodium mealnorm by 0.11 g. Dicts update: 
meal_norm['Sodium(g)'] += 0.11
sum_norm['Sodium(g)'] += 0.22
print (meal_norm)
print (sum_norm)
# Out:
# {'Energy(kcal)': 870.0, 'Fat(g)': 29.099999999999998, 'Carbohydrates(g)': 126.3, 'Fiber(g)': 6.0, 'Protein(g)': 26.099999999999998, 'Sodium(g)': 0.5}
# {'Energy(kcal)': 1740.0, 'Fat(g)': 58.199999999999996, 'Carbohydrates(g)': 252.6, 'Fiber(g)': 12.0, 'Protein(g)': 52.199999999999996, 'Sodium(g)': 1.0}

# %% [markdown]
# ### Visualizations

# %%
# all means for McD and SB menu
means = menu_df.groupby ('McD=0_SB=1').mean()
means.plot(kind = 'bar')

# %%
# All mean caloric values:
means_all = menu_df.groupby (['McD=0_SB=1', 'Category', 'Kind']).mean()
means_all['Energy(kcal)'].plot(kind = 'bar', subplots = False, sharex=True, sharey=False, width = 0.5, figsize = (10,5))

# %%
# All mean nutrition values:
means_all[['Fat(g)', 
          'Carbohydrates(g)', 
          'Fiber(g)', 
          'Protein(g)', 
          'Sodium(g)']].plot(kind = 'bar', subplots = False, sharex=True, sharey=False, width = 1, figsize = (17,5))

# %% [markdown]
# ### Idea for core algorithm for menu making
# 1. Normalize values of all items by dividing them on meal_norm values dict. <b>[DONE]</b>
# 2. Develop the format of breakfast / dinner (for instance, [1-st food item, 2-nd food item, 3-rd drink item]) <b>[DONE]</b>
# 3. Build a meal-maker function (dataset, format) which returns a result_dataset of combitations of items from dataset categories specified in format template <b>[DONE]</b>
# 4. Build an quality assement function, which recieves result_dataset and evaluate caloric and nutrition: 6 total values derived from all items in certain meal combitation and returns 'B-index' (Balance index): how that combination fits the norms. If 'B-index' close to 0 (StDev of six values that normalized as share of 1, noted above in p.1) the meal combination well fitted <b>[DONE]</b>
# 5. Evaluation of SB VS McD menus by this algorithm and draw the conclusions

# %%
# normalizing whole dataset for meal_norm --> new features:
for item in menu_df[['Energy(kcal)','Fat(g)', 'Carbohydrates(g)','Fiber(g)', 'Protein(g)', 'Sodium(g)']]:
    for key in meal_norm:
        if key == item:
            menu_df['n_'+item] = menu_df[item] / float (meal_norm[key])

menu_df
# menu_df.to_csv('menu_normalized.csv')
# Out:
#      McD=0_SB=1 Category         Kind  \
# 0             1     food       Bakery
# 1             1     food       Bakery
# 2             1     food       Bakery
# 3             1     food       Bakery
# 4             1     food       Bakery
# 5             1     food       Bakery
# 6             1     food       Bakery
# 7             1     food       Bakery
# 8             1     food       Bakery
# 9             1     food       Bakery
# 10            1     food       Bakery
# 11            1     food       Bakery
# 12            1     food       Bakery
# 13            1     food       Bakery
# 14            1     food       Bakery
# 15            1     food       Bakery
# 16            1     food       Bakery
# 17            1     food       Bakery
# 18            1     food       Bakery
# 19            1     food       Bakery
# 20            1     food       Bakery
# 21            1     food       Bakery
# 22            1     food       Bakery
# 23            1     food       Bakery
# 24            1     food       Bakery
# 25            1     food       Bakery
# 26            1     food       Bakery
# 27            1     food       Bakery
# 28            1     food       Bakery
# 29            1     food       Bakery
# ..          ...      ...          ...
# 470           0    drink  Cold Drinks
# 471           0    drink  Cold Drinks
# 472           0    drink  Cold Drinks
# 473           0    drink  Cold Drinks
# 474           0    drink  Cold Drinks
# 475           0    drink  Cold Drinks
# 476           0    drink  Cold Drinks
# 477           0    drink  Cold Drinks
# 478           0    drink  Cold Drinks
# 479           0    drink  Cold Drinks
# 480           0    drink  Cold Drinks
# 481           0    drink  Cold Drinks
# 482           0    drink  Cold Drinks
# 483           0    drink  Cold Drinks
# 484           0    drink  Cold Drinks
# 485           0    drink  Cold Drinks
# 486           0    drink  Cold Drinks
# 487           0    drink  Cold Drinks
# 488           0    drink  Cold Drinks
# 489           0    drink  Cold Drinks
# 490           0    drink  Cold Drinks
# 491           0    drink  Cold Drinks
# 492           0    drink  Cold Drinks
# 493           0    drink  Cold Drinks
# 494           0    drink  Cold Drinks
# 495           0    drink  Cold Drinks
# 496           0    drink  Cold Drinks
# 497           0    drink  Cold Drinks
# 498           0    drink  Cold Drinks
# 499           0    drink  Cold Drinks
#
#                                              Item  Energy(kcal)  Fat(g)  \
# 0                                    Chonga Bagel           300     5.0
# 1                                    8-Grain Roll           380     6.0
# 2                                Almond Croissant           410    22.0
# 3                                Banana Nut Bread           420    22.0
# 4                               Birthday Cake Pop           170     9.0
# 5                                Blueberry Muffin           360    15.0
# 6                              Blueberry Oat Cake           390    12.0
# 7                                 Blueberry Scone           420    17.0
# 8                                Butter Croissant           240    12.0
# 9                                   Cheese Danish           320    16.0
# 10                             Chocolate Cake Pop           160     8.0
# 11                          Chocolate Chip Cookie           310    15.0
# 12           Chocolate Chip Cookie Dough Cake Pop           180     9.0
# 13                            Chocolate Croissant           330    18.0
# 14                          Cinnamon Raisin Bagel           270     1.0
# 15                            Classic Coffee Cake           390    16.0
# 16                          Confetti Sugar Cookie           410    21.0
# 17                 Double Chocolate Chunk Brownie           490    28.0
# 18   Everybody's Favorite - Bantam Bagel (2 Pack)           100     3.5
# 19                   Everything Bagel with Cheese           290     3.5
# 20          French Toast - Bantam Bagels (2 Pack)           200     8.0
# 21                      Frosted Doughnut Cake Pop           390    23.0
# 22              Gluten-Free Marshmallow Dream Bar           240     5.0
# 23                           Iced Lemon Loaf Cake           470    20.0
# 24                                    Morning Bun           420    22.0
# 25                  Old-Fashioned Glazed Doughnut           480    27.0
# 26                      Petite Vanilla Bean Scone           120     4.5
# 27                                    Plain Bagel           280     1.5
# 28                                  Pumpkin Bread           410    15.0
# 29                    Pumpkin Cream Cheese Muffin           350    14.0
# ..                                            ...           ...     ...
# 470             Iced Nonfat Caramel Mocha (Large)           370     6.0
# 471                          Frappe Mocha (Small)           450    18.0
# 472                         Frappe Mocha (Medium)           550    22.0
# 473                          Frappe Mocha (Large)           670    26.0
# 474                        Frappe Caramel (Small)           450    19.0
# 475                       Frappe Caramel (Medium)           550    23.0
# 476                        Frappe Caramel (Large)           670    27.0
# 477                 Frappe Chocolate Chip (Small)           530    23.0
# 478                Frappe Chocolate Chip (Medium)           630    26.0
# 479                 Frappe Chocolate Chip (Large)           760    31.0
# 480        Blueberry Pomegranate Smoothie (Small)           220     0.5
# 481       Blueberry Pomegranate Smoothie (Medium)           260     1.0
# 482        Blueberry Pomegranate Smoothie (Large)           340     1.0
# 483            Strawberry Banana Smoothie (Small)           210     0.5
# 484           Strawberry Banana Smoothie (Medium)           250     1.0
# 485            Strawberry Banana Smoothie (Large)           330     1.0
# 486              Mango Pineapple Smoothie (Small)           210     0.5
# 487             Mango Pineapple Smoothie (Medium)           260     1.0
# 489  0.515464            0.680918    0.000000      0.421456         0.32
# 490  0.652921            0.863025    0.000000      0.536398         0.40
# 491  0.790378            1.068884    0.000000      0.689655         0.52
# 492  0.549828            0.712589    0.000000      0.459770         0.32
# 493  0.687285            0.902613    0.000000      0.574713         0.42
# 494  0.824742            1.108472    0.000000      0.689655         0.52
# 495  0.549828            0.720507    0.166667      0.459770         0.48
# 496  0.687285            0.902613    0.333333      0.574713         0.60
# 497  0.790378            1.116390    0.333333      0.727969         0.76
# 498  0.652921            0.863025    0.000000      0.536398         0.42
# 499  0.790378            1.068884    0.000000      0.689655         0.52
#
# [418 rows x 16 columns]

# %%
# how many items of McD / SB remains:
menu_df.groupby(by=['McD=0_SB=1']).count()
# Out:
#             Category  Kind  Item  Energy(kcal)  Fat(g)  Carbohydrates(g)  \
# McD=0_SB=1
# 0                201   201   201           201     201               201
# 1                217   217   217           217     217               217
#
#             Fiber(g)  Protein(g)  Sodium(g)  n_Energy(kcal)  n_Fat(g)  \
# McD=0_SB=1
# 0                201         201        201             201       201
# 1                217         217        217             217       217
#
#             n_Carbohydrates(g)  n_Fiber(g)  n_Protein(g)  n_Sodium(g)
# McD=0_SB=1
# 0                          201         201           201          201
# 1                          217         217           217          217

# %%
# splitting data to two subsets, reindexing:
SB_menu = menu_df.iloc[0:217]
SB_menu.drop(['McD=0_SB=1', 'Energy(kcal)', 'Fat(g)', 'Carbohydrates(g)', 'Fiber(g)', 'Protein(g)', 'Sodium(g)'], axis=1, inplace=True)
SB_menu.reset_index(drop=True, inplace=True)
McD_menu = menu_df.iloc[217:]
McD_menu.drop(['McD=0_SB=1', 'Energy(kcal)', 'Fat(g)', 'Carbohydrates(g)', 'Fiber(g)', 'Protein(g)', 'Sodium(g)'], axis=1, inplace=True)
McD_menu.reset_index(drop=True, inplace=True)
# Out:
# C:\Users\u1\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
McD_menu['Kind'].unique()
# Out:
# array(['Hot Breakfast', 'Sandwiches/Burgers', 'Salads', 'Chiken Snacks',
#        'Sweets/Desserts', 'Snacks', 'Cold Drinks', 'Hot Drinks'],
#       dtype=object)

# %%
SB_menu['Kind'].unique()
# Out:
# array(['Bakery', 'Salads', 'Cold Sandwiches', 'Protein Boxes & Bowls',
#        'Warm Sandwiches', 'Yogurt & Custard', 'Soups', 'Hot Breakfast',
#        'Biscotti & Cookies', 'Chocolates & Candy', 'Fruit & Nuts',
#        'Popcorn & Chips', 'Meat & Cheese', 'Snack Bars', 'Cold Drinks',
#        'Hot Drinks'], dtype=object)

# %%
# for SB menu-based let's assume menus following kinds. The groups could be
# combined to obtain from 2 to 5-positional meal. Lists of item groups:
SB_b_first = ['Soups', 'Salads', 'Protein Boxes & Bowls', 'Hot Breakfast']
SB_b_second = ['Bakery', 'Cold Sandwiches', 'Warm Sandwiches']
SB_desserts = ['Chocolates & Candy', 'Fruit & Nuts', 'Biscotti & Cookies', 'Yogurt & Custard']
SB_snacks = ['Meat & Cheese', 'Snack Bars', 'Fruit & Nuts', 'Popcorn & Chips']
SB_drinks = ['Cold Drinks', 'Hot Drinks']

# a set of groups for combinations --> 3-item 'solid breakfast' as example
SB_solid_b = [SB_b_first, SB_b_second, SB_drinks] 

full_menu = list(product(*SB_solid_b))
full_menu
# Out:
# [('Soups', 'Bakery', 'Cold Drinks'),
#  ('Soups', 'Bakery', 'Hot Drinks'),
#  ('Soups', 'Cold Sandwiches', 'Cold Drinks'),
#  ('Soups', 'Cold Sandwiches', 'Hot Drinks'),
#  ('Soups', 'Warm Sandwiches', 'Cold Drinks'),
#  ('Soups', 'Warm Sandwiches', 'Hot Drinks'),
#  ('Salads', 'Bakery', 'Cold Drinks'),
#  ('Salads', 'Bakery', 'Hot Drinks'),
#  ('Salads', 'Cold Sandwiches', 'Cold Drinks'),
#  ('Salads', 'Cold Sandwiches', 'Hot Drinks'),
#  ('Salads', 'Warm Sandwiches', 'Cold Drinks'),
#  ('Salads', 'Warm Sandwiches', 'Hot Drinks'),
#  ('Protein Boxes & Bowls', 'Bakery', 'Cold Drinks'),
#  ('Protein Boxes & Bowls', 'Bakery', 'Hot Drinks'),
#  ('Protein Boxes & Bowls', 'Cold Sandwiches', 'Cold Drinks'),
#  ('Protein Boxes & Bowls', 'Cold Sandwiches', 'Hot Drinks'),
#  ('Protein Boxes & Bowls', 'Warm Sandwiches', 'Cold Drinks'),
#  ('Protein Boxes & Bowls', 'Warm Sandwiches', 'Hot Drinks'),
#  ('Hot Breakfast', 'Bakery', 'Cold Drinks'),
#  ('Hot Breakfast', 'Bakery', 'Hot Drinks'),
#  ('Hot Breakfast', 'Cold Sandwiches', 'Cold Drinks'),
#  ('Hot Breakfast', 'Cold Sandwiches', 'Hot Drinks'),
#  ('Hot Breakfast', 'Warm Sandwiches', 'Cold Drinks'),
#  ('Hot Breakfast', 'Warm Sandwiches', 'Hot Drinks')]

# %%
# Let's design the breakfast / dinner formats ('kinds') from above catrgories.

k1, k2, k3 = [], [], []

kinds = full_menu[0]

def kind_lists (row, args=kinds):
    
    '''making lists of all items that matches with respective kind in 'kinds' format
    3 kind-format --> 3 lists of items'''

    if kinds[0] in row[1]:
        k1.append (list ([row[2], row[3], row[4], row[5], row[6], row[7], row[8]])) # Well, not so
    if kinds[1] in row[1]:
        k2.append (list ([row[2], row[3], row[4], row[5], row[6], row[7], row[8]])) # elegant code...
    if kinds[2] in row[1]:
        k3.append (list ([row[2], row[3], row[4], row[5], row[6], row[7], row[8]])) # slices --> kernel dies
    
    return k1,k2,k3

SB_menu.apply (kind_lists, axis=1)

# make all non-repeated element-wise combinations of items (by default of 3 items = len (kinds))
arrs = [k1, k2, k3]
combinator = list(product(*arrs))
df_combi = pd.DataFrame (combinator)
df_combi.head()
# Out:
#                                                    0  \
# 0  [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# 1  [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# 2  [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# 3  [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# 4  [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
#
#                                                    1  \
# 0  [Chonga Bagel, 0.3448275862068966, 0.171821305...
# 1  [Chonga Bagel, 0.3448275862068966, 0.171821305...
# 2  [Chonga Bagel, 0.3448275862068966, 0.171821305...
# 3  [Chonga Bagel, 0.3448275862068966, 0.171821305...
# 4  [Chonga Bagel, 0.3448275862068966, 0.171821305...
#
#                                                    2
# 0  [Cool Lime Starbucks Refreshers Beverage, 0.05...
# 1  [Strawberry Acai Starbucks Refreshers Beverage...
# 2  [Vegan Superberry Aeae, 0.39080459770114945, 0...
# 3  [Very Berry Hibiscus Starbucks Refreshers Beve...
# 4  [Evolution FreshOrganic Ginger Limeade, 0.1264...

# %%
len (df_combi)
# Out:
# 4284

# %%
# Let's evaluate all these combinations by their B-index. 
# (possibly it could be designed with more pythonic and elegant code =)

'''df-applied functions calculate inversions of weighted sums. Next is calculating 
    of B-index as mean of weighted (described above) values in row of elements 
    representing a cetrain meal variant. Returns same df featured by 6 inversed
    weighted sums and B_index column.
    
    So the more B_index equal to 1, the more balanced items combination we found.
    If 'B-index' close to 1 (mean of six inv. values that normalized (weighted ) 
    as share of 1, noted above in p.1) then meal combination well fitted.'''

def e_sum (row):
    
    e_sum = row[0][1] + row[1][1] + row[2][1]
    return 1/e_sum
    
def f_sum (row):   
    
    f_sum = row[0][2] + row[1][2] + row[2][2]
    return 1/f_sum
    
def c_sum (row):       
    
    c_sum = row[0][3] + row[1][3] + row[2][3]
    return 1/c_sum
    
def fi_sum (row):  
    fi_sum = row[0][4] + row[1][4] + row[2][4]
    return 1/fi_sum
    
def p_sum (row): 
    
    p_sum = row[0][5] + row[1][5] + row[2][5]
    return 1/p_sum
    
def s_sum (row):

    s_sum = row[0][6] + row[1][6] + row[2][6]
    return 1/s_sum

# %%
# inversed weighted sums for each estimated value for control:
# values < 1 --> norm not reached, 
# values > 1 --> norm exceeded,
# values ≈ 1 --> best fitted to norms
df_combi['Energy'] = df_combi.apply (e_sum, axis=1)
df_combi['Fat'] = df_combi.apply (f_sum, axis=1)
df_combi['Carbohydrates'] = df_combi.apply (c_sum, axis=1)
df_combi['Fiber'] = df_combi.apply (fi_sum, axis=1)
df_combi['Protein'] = df_combi.apply (p_sum, axis=1)
df_combi['Sodium'] = df_combi.apply (s_sum, axis=1)

# finally, B-index: mean of inversed weighted sums:
df_combi['B_index'] = df_combi.iloc[:,3:].mean(axis=1)
df_combi
# Out:
#                                                       0  \
# 0     [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# 1     [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# 2     [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# 3     [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# 4     [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# 5     [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# 6     [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# 7     [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# 8     [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# 9     [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# 10    [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# 11    [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# 12    [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# 13    [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# 14    [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# 15    [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# 16    [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# 17    [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# 18    [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# 19    [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# 20    [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# 21    [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# 22    [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# 23    [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# 24    [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# 25    [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# 26    [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# 27    [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# 28    [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# 29    [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# ...                                                 ...
# 4254  [Organic Tomato Basil Soup, 0.1954022988505747...
# 4255  [Organic Tomato Basil Soup, 0.1954022988505747...
# 4256  [Organic Tomato Basil Soup, 0.1954022988505747...
# 4257  [Organic Tomato Basil Soup, 0.1954022988505747...
# 4258  [Organic Tomato Basil Soup, 0.1954022988505747...
# 4259  [Organic Tomato Basil Soup, 0.1954022988505747...
# 4260  [Organic Tomato Basil Soup, 0.1954022988505747...
# 4261  [Organic Tomato Basil Soup, 0.1954022988505747...
# 4262  [Organic Tomato Basil Soup, 0.1954022988505747...
# 4263  [Organic Tomato Basil Soup, 0.1954022988505747...
# 4264  [Organic Tomato Basil Soup, 0.1954022988505747...
# 4265  [Organic Tomato Basil Soup, 0.1954022988505747...
# 4266  [Organic Tomato Basil Soup, 0.1954022988505747...
# 4267  [Organic Tomato Basil Soup, 0.1954022988505747...
# 4268  [Organic Tomato Basil Soup, 0.1954022988505747...
# 4269  [Organic Tomato Basil Soup, 0.1954022988505747...
# 4270  [Organic Tomato Basil Soup, 0.1954022988505747...
# 4271  [Organic Tomato Basil Soup, 0.1954022988505747...
# 4272  [Organic Tomato Basil Soup, 0.1954022988505747...
# 4273  [Organic Tomato Basil Soup, 0.1954022988505747...
# 4274  [Organic Tomato Basil Soup, 0.1954022988505747...
# 4275  [Organic Tomato Basil Soup, 0.1954022988505747...
# 4276  [Organic Tomato Basil Soup, 0.1954022988505747...
# 4277  [Organic Tomato Basil Soup, 0.1954022988505747...
# 4278  [Organic Tomato Basil Soup, 0.1954022988505747...
# 4279  [Organic Tomato Basil Soup, 0.1954022988505747...
# 4280  [Organic Tomato Basil Soup, 0.1954022988505747...
# 4275       1.706757  2.000000  1.631250  1.351351  1.575905
# 4276       1.387912  2.000000  1.373684  1.086957  1.364391
# 4277       1.559259  2.000000  1.242857  1.190476  1.419175
# 4278       1.169444  2.000000  1.087500  1.851852  1.417481
# 4279       1.857353  2.000000  2.175000  1.063830  1.727280
# 4280       1.214423  1.200000  2.007692  1.020408  1.345720
# 4281       1.754167  1.500000  2.007692  1.111111  1.583061
# 4282       1.302062  0.545455  0.900000  1.136364  1.051458
# 4283       1.214423  0.600000  1.044000  1.250000  1.121610
#
# [4284 rows x 10 columns]

# %%
# df for comparisons of McD/SB:
# prefixes means restraunt name (McD/SB), kind of meal (breakfast/dinner == 'b' or 'd')
# and version of subset (at least 3 versions in each)
index_df = pd.DataFrame (df_combi['B_index']) # len = 2340
index_df.rename(columns={'B_index': 'SB_b_1'}, inplace=True)
index_df.head()
# Out:
#      SB_b_1
# 0  1.757216
# 1  1.658781
# 2  0.958452
# 3  1.685452
# 4  1.663141

# %% [markdown]
# ### Results analytics in terms of weighted sums & B-index

# %%
# 10 breakfast sets with lowest (== best fitted) values:
df_combi['B_index'].sort_values().head(10)
# Out:
# 4093    0.798007
# 3778    0.810480
# 1951    0.818470
# 2581    0.821816
# 2329    0.822175
# 3715    0.822626
# 3967    0.823444
# 1636    0.829271
# 3652    0.842717
# 4094    0.848461
# Name: B_index, dtype: float64

# %%
# 303 is the best. Who is this hero?
df_combi.loc[303,:]

# Well, of course oatmeal in =) Looks great but with little dificit, excepting fiber
# (the closer certain weighted sum to 1 the better it fitted on respective value in given combination)
# Out:
# 0                [Chicken Quinoa Soup, 0.13793103448275862, 0.1...
# 1                [Birthday Cake Pop, 0.19540229885057472, 0.309...
# 2                [Iced Caramel Macchiato, 0.28735632183908044, ...
# Energy                                                     1.61111
# Fat                                                        1.49231
# Carbohydrates                                              1.80429
# Fiber                                                            6
# Protein                                                     1.0875
# Sodium                                                     1.92308
# B_index                                                    2.31971
# Name: 303, dtype: object

# %%
# And who will be anti-hero?
df_combi['B_index'].sort_values(ascending=False).head(10)
# df_combi.loc[2077,:]
# children will be overdosed by fat, proteins and salt, 
# whereas 'fast' energy from carbohydrates in deficit...
# Out:
# 1676    4.036985
# 1680    4.033523
# 1679    3.997448
# 1662    3.851343
# 1660    3.851343
# 1664    3.851343
# 1675    3.795062
# 1176    3.773616
# 2054    3.770712
# 794     3.770712
# Name: B_index, dtype: float64

# %%
# mean B-index of the subset:
df_combi['B_index'].mean()
# Out:
# 1.7442901626965492

# %%
# only 11 (from 2340!) combinations did not exceed B_index = 0.166
# and only 112 combinations did not > 0.235
df_combi['B_index'].value_counts(bins=10, normalize=False)
# Out:
# (1.446, 1.77]     1285
# (1.122, 1.446]    1127
# (1.77, 2.094]      542
# (0.794, 1.122]     412
# (2.094, 2.417]     301
# (2.741, 3.065]     210
# (3.065, 3.389]     163
# (2.417, 2.741]     162
# (3.389, 3.713]      66
# (3.713, 4.037]      16
# Name: B_index, dtype: int64

# %%
df_combi['B_index'].value_counts(bins=10).plot(kind = 'bar')
