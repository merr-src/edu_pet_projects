# %% [markdown]
# ## Educational analytic case with McDonalds and Starbucks menu: what would be better as meals for teens?

# %% [markdown]
# [Case description] Restrictions from the task description [Restrictions, document-1 = link, document-2 = link]
#
# DONE:
# - values from norms (document-1) extracted manually --> txt --> dict. We find only 6 values: Energy(kcal), Fat(g), Carbohydrates(g), Fiber(g), Protein(g), Sodium (g), wich exist in all three datasets (document-1, McD and SB menus)
# - values from McD and SB .csv menus --> Excel --> (processing: combine, add features in cols, enrichment)
# - features added: (1) 'McD=0_SB=1': restraunt coding, (2) 'Category': food/drink, (3) 'Kind': bakery/breakfast/hot drink etc.
# - dataset enriched manually: about 60 items in 'Snacks & sweets' category were added for SB menu. Thus we have more balanced dataaset (McD/SB share).
# - discard from zeroes: dividing all mass values by 1000 (mg --> g)
# - several bug fixes in values
# - deleted items with all zeroes
# - calculate weighted norms - according the rule requirement from official document-2
# - deleting dishes with > 60% (breakfast + dinner) of day norm caloric or nutrition values (for instance, 1880 kcal (40 pieces of chicken McNuggets)
#
# PLAN:
# - include potential allergics - new feature?
# - add the data on serving sizes
# - search for nutrition indices or calculate integrated nutrition index (may be Carb:Fat:Prot matching those in norms?) and visualize it
# - develop the decision making algorithm for combining potential breakfast and dinner sets
# - test the algorithm, corrections
# - extract the results, preference for hot dishes and moderate-sugared drinks

# %%
# required imports
import pandas as pd
import numpy as np
from itertools import product
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Official norms

# %%
# Dict with actual norms (from official document-1)
norms = {}

f = open ('actual_norms.txt')

for line in f:
    line = line.strip().split(',')
    norms[line[0]] = line[1]
    
del norms['Item']
norms
# Out:
# {'Energy(kcal)': '2900',
#  'Fat(g)': '97',
#  'Carbohydrates(g)': '421',
#  'Fiber(g)': '20',
#  'Protein(g)': '87',
#  'Sodium(g)': '1.3'}

# %%
# (From official document-2): 
# -breakfast + dinner = 20-25% + 30-35% daily energy value respectively --> 
# 25% and 35% (max due to sports competitions)
# -breakfast + dinner = 55-60% total daily nutrients value --> 
# 25% and 35% (max due to sports competitions)
# (only breakfast and dinner mentioned in the task)

# calculating weighted norms:

breakfast_norm, dinner_norm = {},{}

for key, value in norms.items():
    breakfast_norm[key] = float(value)*0.25
    dinner_norm[key] = float(value)*0.35
    
# sum_norm dict for data filtering (del items which contain greater values). Via dict generator:   
sum_norm = {key:float(value)*0.6 for key, value in norms.items()}
    
print (breakfast_norm)
print (dinner_norm)
print (sum_norm)
# Out:
# {'Energy(kcal)': 725.0, 'Fat(g)': 24.25, 'Carbohydrates(g)': 105.25, 'Fiber(g)': 5.0, 'Protein(g)': 21.75, 'Sodium(g)': 0.325}
# {'Energy(kcal)': 1014.9999999999999, 'Fat(g)': 33.949999999999996, 'Carbohydrates(g)': 147.35, 'Fiber(g)': 7.0, 'Protein(g)': 30.45, 'Sodium(g)': 0.45499999999999996}
# {'Energy(kcal)': 1740.0, 'Fat(g)': 58.199999999999996, 'Carbohydrates(g)': 252.6, 'Fiber(g)': 12.0, 'Protein(g)': 52.199999999999996, 'Sodium(g)': 0.78}

# %% [markdown]
# ### McD & SB menus

# %%
# Starbucks (SB) and McDonalds (McD) combined menu in single df: 
menu_df = pd.read_csv ('combined_menu_300919.csv', sep=';', encoding = 'koi8-r')
menu_df.head()
# Out:
#    McD=0_SB=1 Category    Kind               Item  Energy(kcal)  Fat(g)  \
# 0           1     food  Bakery       Chonga Bagel           300     5.0
# 1           1     food  Bakery       8-Grain Roll           380     6.0
# 2           1     food  Bakery   Almond Croissant           410    22.0
# 3           1     food  Bakery   Banana Nut Bread           420    22.0
# 4           1     food  Bakery  Birthday Cake Pop           170     9.0
#
#    Carbohydrates(g)  Fiber(g)  Protein(g)  Sodium(g)
# 0                50       3.0          12       0.53
# 1                70       7.0          10       0.43
# 2                45       3.0          10       0.39
# 3                52       2.0           6       0.32
# 4                23       0.0           1       0.11

# %%
# checking data gaps - it's OK
menu_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
# McD=0_SB=1          500 non-null int64
# Category            500 non-null object
# Kind                500 non-null object
# Item                500 non-null object
# Energy(kcal)        500 non-null int64
# Fat(g)              500 non-null float64
# Carbohydrates(g)    500 non-null int64
# Fiber(g)            500 non-null float64
# Protein(g)          500 non-null int64
# Sodium(g)           500 non-null float64
# dtypes: float64(3), int64(4), object(3)
# memory usage: 39.1+ KB

# %% [markdown]
# ### Clean the data

# %%
# any all-zero items to delete?
del_list = []
def find_zeroes (row):
    '''the function recieve row of a df and process it: if all quantitative fields 
    are zeroes in the row, the row included in list for deleting'''
    if row[4:].sum() == 0:
#         print (row)
        del_list.append (row[3])
        
menu_df.apply (find_zeroes, axis = 1)
menu_df = menu_df.loc[~menu_df['Item'].isin(del_list)]
len (menu_df) # 7 values deleted
# Out:
# 493

# %%
# filtering: del items which contain values greater than weighted norm in sum_norm dict:

menu_df[menu_df['Energy(kcal)']>=sum_norm['Energy(kcal)']]
# only 1 item exceeds sum_norms (1740 kcal)
# Out:
#      McD=0_SB=1 Category                      Kind  \
# 322           0     food  Lunch/Sandwiches/Burgers
#
#                              Item  Energy(kcal)  Fat(g)  Carbohydrates(g)  \
# 322  Chicken McNuggets (40 piece)          1880   118.0               118
#
#      Fiber(g)  Protein(g)  Sodium(g)
# 322       6.0          87        3.6

# %%
menu_df[menu_df['Fat(g)']>=sum_norm['Fat(g)']]
# 3 items exceed sum_norms (58.2 g)
# Out:
#      McD=0_SB=1 Category                      Kind  \
# 272           0     food             Hot Breakfast
# 321           0     food  Lunch/Sandwiches/Burgers
# 322           0     food  Lunch/Sandwiches/Burgers
#
#                                             Item  Energy(kcal)  Fat(g)  \
# 272  Big Breakfast with Hotcakes (Large Biscuit)          1150    60.0
# 321                 Chicken McNuggets (20 piece)           940    59.0
# 322                 Chicken McNuggets (40 piece)          1880   118.0
#
#      Carbohydrates(g)  Fiber(g)  Protein(g)  Sodium(g)
# 272               116       7.0          36       2.26
# 321                59       3.0          44       1.80
# 322               118       6.0          87       3.60

# %%
menu_df[menu_df['Carbohydrates(g)']>=sum_norm['Carbohydrates(g)']]
# no items exceed sum_norms
# Out:
# Empty DataFrame
# Columns: [McD=0_SB=1, Category, Kind, Item, Energy(kcal), Fat(g), Carbohydrates(g), Fiber(g), Protein(g), Sodium(g)]
# Index: []

# %%
menu_df[menu_df['Fiber(g)']>=sum_norm['Fiber(g)']]
# 2 items exceed sum_norms (12.0 g)
# Out:
#      McD=0_SB=1 Category                   Kind  \
# 56            1     food  Protein Boxes & Bowls
# 114           1     food           Fruit & Nuts
#
#                                                  Item  Energy(kcal)  Fat(g)  \
# 56   Lentils & Vegetable Protein Bowl with Brown Rice           650    29.0
# 114                                 Bare Fruit Medley           130     0.0
#
#      Carbohydrates(g)  Fiber(g)  Protein(g)  Sodium(g)
# 56                 80      21.0          23       0.67
# 114                31      24.0           1       0.00

# %%
menu_df[menu_df['Protein(g)']>=sum_norm['Protein(g)']]
# only 1 item exceeds sum_norms (52.2 g)
# Out:
#      McD=0_SB=1 Category                      Kind  \
# 322           0     food  Lunch/Sandwiches/Burgers
#
#                              Item  Energy(kcal)  Fat(g)  Carbohydrates(g)  \
# 322  Chicken McNuggets (40 piece)          1880   118.0               118
#
#      Fiber(g)  Protein(g)  Sodium(g)
# 322       6.0          87        3.6

# %%
menu_df[menu_df['Sodium(g)']>=sum_norm['Sodium(g)']]
# Wow! 104 items exceed sum_norms (0.78 g)
# Out:
#      McD=0_SB=1 Category                      Kind  \
# 36            1     food     Lunch/Cold Sandwiches
# 37            1     food     Lunch/Cold Sandwiches
# 38            1     food     Protein Boxes & Bowls
# 40            1     food     Lunch/Warm Sandwiches
# 41            1     food     Lunch/Warm Sandwiches
# 43            1     food     Lunch/Cold Sandwiches
# 44            1     food     Lunch/Warm Sandwiches
# 45            1     food     Lunch/Warm Sandwiches
# 46            1     food     Lunch/Warm Sandwiches
# 48            1     food     Lunch/Warm Sandwiches
# 49            1     food                    Salads
# 51            1     food     Protein Boxes & Bowls
# 52            1     food     Protein Boxes & Bowls
# 53            1     food     Protein Boxes & Bowls
# 58            1     food     Protein Boxes & Bowls
# 61            1     food             Hot Breakfast
# 62            1     food             Hot Breakfast
# 64            1     food             Hot Breakfast
# 68            1     food             Hot Breakfast
# 69            1     food             Hot Breakfast
# 70            1     food             Hot Breakfast
# 75            1     food             Hot Breakfast
# 76            1     food             Hot Breakfast
# 77            1     food     Lunch/Warm Sandwiches
# 78            1     food     Lunch/Warm Sandwiches
# 79            1     food     Lunch/Warm Sandwiches
# 80            1     food     Lunch/Warm Sandwiches
# 81            1     food     Lunch/Warm Sandwiches
# 83            1     food     Lunch/Warm Sandwiches
# 242           0     food             Hot Breakfast
# ..          ...      ...                       ...
# 295           0     food  Lunch/Sandwiches/Burgers
# 296           0     food  Lunch/Sandwiches/Burgers
# 297           0     food  Lunch/Sandwiches/Burgers
# 298           0     food  Lunch/Sandwiches/Burgers
# 299           0     food  Lunch/Sandwiches/Burgers
# 300           0     food  Lunch/Sandwiches/Burgers
# 301           0     food  Lunch/Sandwiches/Burgers
# 302           0     food  Lunch/Sandwiches/Burgers
# 303           0     food  Lunch/Sandwiches/Burgers
# 304           0     food  Lunch/Sandwiches/Burgers
# 300              Premium Grilled Chicken Club Sandwich           510    20.0
# 301          Premium Crispy Chicken Ranch BLT Sandwich           610    28.0
# 302         Premium Grilled Chicken Ranch BLT Sandwich           450    15.0
# 303            Bacon Clubhouse Crispy Chicken Sandwich           750    38.0
# 304           Bacon Clubhouse Grilled Chicken Sandwich           590    25.0
# 305             Southern Style Crispy Chicken Sandwich           430    19.0
# 306                                          McChicken           360    16.0
# 307                            Bacon Cheddar McChicken           480    24.0
# 308                      Bacon Buffalo Ranch McChicken           430    21.0
# 309                            Buffalo Ranch McChicken           360    16.0
# 310    Premium McWrap Chicken & Bacon (Crispy Chicken)           630    32.0
# 311   Premium McWrap Chicken & Bacon (Grilled Chicken)           480    19.0
# 312    Premium McWrap Chicken & Ranch (Crispy Chicken)           610    31.0
# 313   Premium McWrap Chicken & Ranch (Grilled Chicken)           450    18.0
# 314  Premium McWrap Southwest Chicken (Crispy Chicken)           670    33.0
# 315  Premium McWrap Southwest Chicken (Grilled Chic...           520    20.0
# 316  Premium McWrap Chicken Sweet Chili (Crispy Chi...           540    23.0
# 317  Premium McWrap Chicken Sweet Chili (Grilled Ch...           380    10.0
# 320                       Chicken McNuggets (10 piece)           470    30.0
# 321                       Chicken McNuggets (20 piece)           940    59.0
# 322                       Chicken McNuggets (40 piece)          1880   118.0
# 325      Premium Bacon Ranch Salad with Crispy Chicken           380    21.0
# 328        Premium Southwest Salad with Crispy Chicken           450    22.0
# 330           Chipotle BBQ Snack Wrap (Crispy Chicken)           340    15.0
# 334                  Ranch Snack Wrap (Crispy Chicken)           360    20.0
#
#      Carbohydrates(g)  Fiber(g)  Protein(g)  Sodium(g)
# 36                 61       5.0          24       0.94
# 37                 55       4.0          22       1.05
# 38                 29       4.0          21       0.88
# 40                 15       4.0          21       1.14
# 41                 52       3.0          22       1.09
# 43                 47       6.0          32       0.86
# 44                 30       5.0          28       0.90
# 45                 46       4.0          18       1.19
# 46                 66       5.0          21       1.20
# 48                 50       4.0          26       1.13
# 49                 67      11.0          27       0.88
# 51                 42       9.0          27       1.03
# 52                 58       7.0          35       1.66
# 53                 45       4.0          20       1.00
# 58                 42       5.0          24       1.62
# 61                 32       1.0          18       0.78
# 62                 35       1.0          26       1.16
# 64                 40       1.0          21       1.05
# 68                 43       0.0          21       0.92
# 69                 34       1.0          18       0.88
# 70                 39       2.0          26       1.17
# 75                 36       0.0          24       0.95
# 76                 34       4.0          20       0.83
# 77                 73       7.0          21       1.30
# 78                 65       3.0          31       1.46
# 79                 58       3.0          28       0.90
# 80                 47       4.0          21       1.06
# 81                 42       0.0          25       1.25
# 83                 55       3.0          34       1.19
# 242                29       4.0          14       0.78
# ..                ...       ...         ...        ...
# 295                35       2.0          22       1.03
# 296                44       3.0          22       0.98
# 297                55       3.0          24       0.99
# 298                42       3.0          28       0.82
# 299                58       3.0          36       1.41
# 300                44       3.0          40       1.25
# 301                57       3.0          32       1.40
# 302                43       3.0          36       1.23
# 303                65       4.0          36       1.72
# 304                51       4.0          40       1.56
# 305                43       2.0          21       0.91
# 306                40       2.0          14       0.80
# 307                43       2.0          22       1.26
# 308                41       2.0          20       1.26
# 309                40       2.0          14       0.99
# 310                56       3.0          32       1.54
# 311                42       3.0          36       1.37
# 312                56       3.0          27       1.34
# 313                42       3.0          30       1.17
# 314                68       5.0          27       1.48
# 315                55       5.0          31       1.32
# 316                61       3.0          23       1.26
# 317                47       3.0          27       1.09
# 320                30       2.0          22       0.90
# 321                59       3.0          44       1.80
# 322               118       6.0          87       3.60
# 325                22       2.0          25       0.86
# 328                42       7.0          23       0.85
# 330                37       1.0          14       0.78
# 334                32       1.0          15       0.81
#
# [104 rows x 10 columns]

# %%
# Well, lets assume that salt needs increases due to sports: 1.0 g sodium threshold:
menu_df[menu_df['Sodium(g)']>=1]
# Nevertheless 73 items exceed 1.0 g
# Out:
#      McD=0_SB=1 Category                      Kind  \
# 37            1     food     Lunch/Cold Sandwiches
# 40            1     food     Lunch/Warm Sandwiches
# 41            1     food     Lunch/Warm Sandwiches
# 45            1     food     Lunch/Warm Sandwiches
# 46            1     food     Lunch/Warm Sandwiches
# 48            1     food     Lunch/Warm Sandwiches
# 51            1     food     Protein Boxes & Bowls
# 52            1     food     Protein Boxes & Bowls
# 53            1     food     Protein Boxes & Bowls
# 58            1     food     Protein Boxes & Bowls
# 62            1     food             Hot Breakfast
# 64            1     food             Hot Breakfast
# 70            1     food             Hot Breakfast
# 77            1     food     Lunch/Warm Sandwiches
# 78            1     food     Lunch/Warm Sandwiches
# 80            1     food     Lunch/Warm Sandwiches
# 81            1     food     Lunch/Warm Sandwiches
# 83            1     food     Lunch/Warm Sandwiches
# 246           0     food             Hot Breakfast
# 247           0     food             Hot Breakfast
# 248           0     food             Hot Breakfast
# 249           0     food             Hot Breakfast
# 250           0     food             Hot Breakfast
# 251           0     food             Hot Breakfast
# 252           0     food             Hot Breakfast
# 253           0     food             Hot Breakfast
# 254           0     food             Hot Breakfast
# 255           0     food             Hot Breakfast
# 256           0     food             Hot Breakfast
# 257           0     food             Hot Breakfast
# ..          ...      ...                       ...
# 271           0     food             Hot Breakfast
# 272           0     food             Hot Breakfast
# 273           0     food             Hot Breakfast
# 274           0     food             Hot Breakfast
# 283           0     food  Lunch/Sandwiches/Burgers
# 284           0     food  Lunch/Sandwiches/Burgers
# 285           0     food  Lunch/Sandwiches/Burgers
# 287           0     food  Lunch/Sandwiches/Burgers
# 290           0     food  Lunch/Sandwiches/Burgers
# 291           0     food  Lunch/Sandwiches/Burgers
# 293           0     food  Lunch/Sandwiches/Burgers
# 295           0     food  Lunch/Sandwiches/Burgers
# 299           0     food  Lunch/Sandwiches/Burgers
# 300           0     food  Lunch/Sandwiches/Burgers
# 301           0     food  Lunch/Sandwiches/Burgers
# 302           0     food  Lunch/Sandwiches/Burgers
# 303           0     food  Lunch/Sandwiches/Burgers
# 304           0     food  Lunch/Sandwiches/Burgers
# 307           0     food  Lunch/Sandwiches/Burgers
# 308           0     food  Lunch/Sandwiches/Burgers
# 310           0     food  Lunch/Sandwiches/Burgers
# 312                56       3.0          27       1.34
# 313                42       3.0          30       1.17
# 314                68       5.0          27       1.48
# 315                55       5.0          31       1.32
# 316                61       3.0          23       1.26
# 317                47       3.0          27       1.09
# 321                59       3.0          44       1.80
# 322               118       6.0          87       3.60
#
# [73 rows x 10 columns]

# %%
# Let's drop out all items that exceeds the criteria:
menu_df = menu_df[menu_df['Energy(kcal)'] < sum_norm['Energy(kcal)']]
menu_df = menu_df[menu_df['Fat(g)'] < sum_norm['Fat(g)']]
menu_df = menu_df[menu_df['Fiber(g)'] < sum_norm['Fiber(g)']]
menu_df = menu_df[menu_df['Protein(g)'] < sum_norm['Protein(g)']]
menu_df = menu_df[menu_df['Sodium(g)'] < 1.0]

len (menu_df)
# Out:
# 418

# %%
# We increased the sodium sum norm 0.78 --> 1.0, i.e. +0.22. 
# Let's assume that in turns it increases breakfast and dinner 
# sodium norms equally: by 0.11 g. Norm dicts update:
breakfast_norm['Sodium(g)'] += 0.11
dinner_norm['Sodium(g)'] += 0.11
sum_norm['Sodium(g)'] += 0.22
print (breakfast_norm)
print (dinner_norm)
print (sum_norm)
# Out:
# {'Energy(kcal)': 725.0, 'Fat(g)': 24.25, 'Carbohydrates(g)': 105.25, 'Fiber(g)': 5.0, 'Protein(g)': 21.75, 'Sodium(g)': 0.435}
# {'Energy(kcal)': 1014.9999999999999, 'Fat(g)': 33.949999999999996, 'Carbohydrates(g)': 147.35, 'Fiber(g)': 7.0, 'Protein(g)': 30.45, 'Sodium(g)': 0.565}
# {'Energy(kcal)': 1740.0, 'Fat(g)': 58.199999999999996, 'Carbohydrates(g)': 252.6, 'Fiber(g)': 12.0, 'Protein(g)': 52.199999999999996, 'Sodium(g)': 1.0}

# %% [markdown]
# ### Visualizations

# %%
# all means for McD and SB menu
means = menu_df.groupby ('McD=0_SB=1').mean()
means.plot(kind = 'bar')

# %%
# All mean caloric values:
means_all = menu_df.groupby (['McD=0_SB=1', 'Category', 'Kind']).mean()
means_all['Energy(kcal)'].plot(kind = 'bar', subplots = False, sharex=True, sharey=False, width = 0.5, figsize = (10,5))

# %%
# All mean nutrition values:
means_all[['Fat(g)', 
          'Carbohydrates(g)', 
          'Fiber(g)', 
          'Protein(g)', 
          'Sodium(g)']].plot(kind = 'bar', subplots = False, sharex=True, sharey=False, width = 1, figsize = (17,5))

# %% [markdown]
# ### Idea for core algorithm for menu making
# 0. Manually splitting the data to two near equal subsets for breakfast and for dinner <b>[PASSED]</b>
# 1. Normalize values of all items in breakfast subset by dividing them on breakfast_norm values dict, and in dinner subset by dividing them on dinner_norm values dict. If [PASSED], make two copies of the whole dataset: normalized for breakfast and  normalized for dinner. <b>[DONE]</b>
# 2. Develop the format of breakfast / dinner (for instance, [1-st food item, 2-nd food item, 3-rd drink item])
# 3. Build a meal-maker function (dataset, format) which returns a result_dataset of random combitations of items from dataset categories specified in format template.
# 4. Build an quality assement function, which recieves result_dataset and evaluate caloric and nutrition: 6 total values derived from all items in certain breakfast / dinner combitation and returns 'Q-index' (how that combination fits the norms). If 'Q-index' close to 0 (StDev of six values that normalized as share of 1, noted above in p.1) the meal combination well fitted.

# %%
# normalizing whole dataset for breakfast --> new features:
for item in menu_df[['Energy(kcal)','Fat(g)', 'Carbohydrates(g)','Fiber(g)', 'Protein(g)', 'Sodium(g)']]:
    for key in breakfast_norm:
        if key == item:
            menu_df['b_'+item] = menu_df[item] / float (breakfast_norm[key])

# and for dinner:
for item in menu_df[['Energy(kcal)','Fat(g)', 'Carbohydrates(g)','Fiber(g)', 'Protein(g)', 'Sodium(g)']]:
    for key in dinner_norm:
        if key == item:
            menu_df['d_'+item] = menu_df[item] / float (dinner_norm[key])

menu_df
# menu_df.to_csv('menu_normalized.csv')
# Out:
#      McD=0_SB=1 Category         Kind  \
# 0             1     food       Bakery
# 1             1     food       Bakery
# 2             1     food       Bakery
# 3             1     food       Bakery
# 4             1     food       Bakery
# 5             1     food       Bakery
# 6             1     food       Bakery
# 7             1     food       Bakery
# 8             1     food       Bakery
# 9             1     food       Bakery
# 10            1     food       Bakery
# 11            1     food       Bakery
# 12            1     food       Bakery
# 13            1     food       Bakery
# 14            1     food       Bakery
# 15            1     food       Bakery
# 16            1     food       Bakery
# 17            1     food       Bakery
# 18            1     food       Bakery
# 19            1     food       Bakery
# 20            1     food       Bakery
# 21            1     food       Bakery
# 22            1     food       Bakery
# 23            1     food       Bakery
# 24            1     food       Bakery
# 25            1     food       Bakery
# 26            1     food       Bakery
# 27            1     food       Bakery
# 28            1     food       Bakery
# 29            1     food       Bakery
# ..          ...      ...          ...
# 470           0    drink  Cold Drinks
# 471           0    drink  Cold Drinks
# 472           0    drink  Cold Drinks
# 473           0    drink  Cold Drinks
# 474           0    drink  Cold Drinks
# 475           0    drink  Cold Drinks
# 476           0    drink  Cold Drinks
# 477           0    drink  Cold Drinks
# 478           0    drink  Cold Drinks
# 479           0    drink  Cold Drinks
# 480           0    drink  Cold Drinks
# 481           0    drink  Cold Drinks
# 482           0    drink  Cold Drinks
# 483           0    drink  Cold Drinks
# 484           0    drink  Cold Drinks
# 485           0    drink  Cold Drinks
# 486           0    drink  Cold Drinks
# 487           0    drink  Cold Drinks
# 488           0    drink  Cold Drinks
# 489           0    drink  Cold Drinks
# 490           0    drink  Cold Drinks
# 491           0    drink  Cold Drinks
# 492           0    drink  Cold Drinks
# 493           0    drink  Cold Drinks
# 494           0    drink  Cold Drinks
# 495           0    drink  Cold Drinks
# 496           0    drink  Cold Drinks
# 497           0    drink  Cold Drinks
# 498           0    drink  Cold Drinks
# 499           0    drink  Cold Drinks
#
#                                              Item  Energy(kcal)  Fat(g)  \
# 0                                    Chonga Bagel           300     5.0
# 1                                    8-Grain Roll           380     6.0
# 2                                Almond Croissant           410    22.0
# 3                                Banana Nut Bread           420    22.0
# 4                               Birthday Cake Pop           170     9.0
# 5                                Blueberry Muffin           360    15.0
# 6                              Blueberry Oat Cake           390    12.0
# 7                                 Blueberry Scone           420    17.0
# 8                                Butter Croissant           240    12.0
# 9                                   Cheese Danish           320    16.0
# 10                             Chocolate Cake Pop           160     8.0
# 11                          Chocolate Chip Cookie           310    15.0
# 12           Chocolate Chip Cookie Dough Cake Pop           180     9.0
# 13                            Chocolate Croissant           330    18.0
# 14                          Cinnamon Raisin Bagel           270     1.0
# 15                            Classic Coffee Cake           390    16.0
# 16                          Confetti Sugar Cookie           410    21.0
# 17                 Double Chocolate Chunk Brownie           490    28.0
# 18   Everybody's Favorite - Bantam Bagel (2 Pack)           100     3.5
# 19                   Everything Bagel with Cheese           290     3.5
# 20          French Toast - Bantam Bagels (2 Pack)           200     8.0
# 21                      Frosted Doughnut Cake Pop           390    23.0
# 22              Gluten-Free Marshmallow Dream Bar           240     5.0
# 23                           Iced Lemon Loaf Cake           470    20.0
# 24                                    Morning Bun           420    22.0
# 25                  Old-Fashioned Glazed Doughnut           480    27.0
# 26                      Petite Vanilla Bean Scone           120     4.5
# 27                                    Plain Bagel           280     1.5
# 28                                  Pumpkin Bread           410    15.0
# 29                    Pumpkin Cream Cheese Muffin           350    14.0
# ..                                            ...           ...     ...
# 470             Iced Nonfat Caramel Mocha (Large)           370     6.0
# 471                          Frappe Mocha (Small)           450    18.0
# 472                         Frappe Mocha (Medium)           550    22.0
# 473                          Frappe Mocha (Large)           670    26.0
# 474                        Frappe Caramel (Small)           450    19.0
# 475                       Frappe Caramel (Medium)           550    23.0
# 476                        Frappe Caramel (Large)           670    27.0
# 477                 Frappe Chocolate Chip (Small)           530    23.0
# 478                Frappe Chocolate Chip (Medium)           630    26.0
# 479                 Frappe Chocolate Chip (Large)           760    31.0
# 480        Blueberry Pomegranate Smoothie (Small)           220     0.5
# 481       Blueberry Pomegranate Smoothie (Medium)           260     1.0
# 482        Blueberry Pomegranate Smoothie (Large)           340     1.0
# 483            Strawberry Banana Smoothie (Small)           210     0.5
# 484           Strawberry Banana Smoothie (Medium)           250     1.0
# 485            Strawberry Banana Smoothie (Large)           330     1.0
# 486              Mango Pineapple Smoothie (Small)           210     0.5
# 487             Mango Pineapple Smoothie (Medium)           260     1.0
# 488              Mango Pineapple Smoothie (Large)           340     1.0
# 489                         Vanilla Shake (Small)           530    15.0
# 490                        Vanilla Shake (Medium)           660    19.0
# 491                         Vanilla Shake (Large)           820    23.0
# 492                      Strawberry Shake (Small)           550    16.0
# 493                     Strawberry Shake (Medium)           690    20.0
# 494                      Strawberry Shake (Large)           850    24.0
# 495                       Chocolate Shake (Small)           560    16.0
# 496                      Chocolate Shake (Medium)           700    20.0
# 497                       Chocolate Shake (Large)           850    23.0
# 498                       Shamrock Shake (Medium)           660    19.0
# 499                        Shamrock Shake (Large)           820    23.0
#
#      Carbohydrates(g)  Fiber(g)  Protein(g)  Sodium(g)  ...  \
# 0                  50       3.0          12      0.530  ...
# 1                  70       7.0          10      0.430  ...
# 2                  45       3.0          10      0.390  ...
# 3                  52       2.0           6      0.320  ...
# 4                  23       0.0           1      0.110  ...
# 5                  52       1.0           5      0.270  ...
# 6                  71       7.0           7      0.430  ...
# 7                  61       2.0           5      0.350  ...
# 8                  28       1.0           5      0.320  ...
# 472     0.283186
# 473     0.336283
# 474     0.221239
# 475     0.283186
# 476     0.336283
# 477     0.238938
# 478     0.283186
# 479     0.353982
# 480     0.070796
# 481     0.088496
# 482     0.115044
# 483     0.088496
# 484     0.106195
# 485     0.141593
# 486     0.070796
# 487     0.079646
# 488     0.106195
# 489     0.283186
# 490     0.353982
# 491     0.460177
# 492     0.283186
# 493     0.371681
# 494     0.460177
# 495     0.424779
# 496     0.530973
# 497     0.672566
# 498     0.371681
# 499     0.460177
#
# [418 rows x 22 columns]

# %%
# how many items of McD / SB remains:
menu_df.groupby(by=['McD=0_SB=1']).count()
# Out:
#             Category  Kind  Item  Energy(kcal)  Fat(g)  Carbohydrates(g)  \
# McD=0_SB=1
# 0                201   201   201           201     201               201
# 1                217   217   217           217     217               217
#
#             Fiber(g)  Protein(g)  Sodium(g)  b_Energy(kcal)  ...  \
# McD=0_SB=1                                                   ...
# 0                201         201        201             201  ...
# 1                217         217        217             217  ...
#
#             b_Carbohydrates(g)  b_Fiber(g)  b_Protein(g)  b_Sodium(g)  \
# McD=0_SB=1
# 0                          201         201           201          201
# 1                          217         217           217          217
#
#             d_Energy(kcal)  d_Fat(g)  d_Carbohydrates(g)  d_Fiber(g)  \
# McD=0_SB=1
# 0                      201       201                 201         201
# 1                      217       217                 217         217
#
#             d_Protein(g)  d_Sodium(g)
# McD=0_SB=1
# 0                    201          201
# 1                    217          217
#
# [2 rows x 21 columns]

# %%
# splitting data to two subsets, reindexing:
SB_menu = menu_df.iloc[0:217]
SB_menu.drop(['McD=0_SB=1'], axis=1, inplace=True)
SB_menu.reset_index(drop=True, inplace=True)
McD_menu = menu_df.iloc[217:]
McD_menu.drop(['McD=0_SB=1'], axis=1, inplace=True)
McD_menu.reset_index(drop=True, inplace=True)

# %%
McD_menu['Kind'].unique()
# Out:
# array(['Hot Breakfast', 'Lunch/Sandwiches/Burgers', 'Salads',
#        'Chiken Snacks', 'Sweets/Desserts', 'Snacks', 'Cold Drinks',
#        'Hot Drinks'], dtype=object)

# %%
SB_menu['Kind'].unique()
# Out:
# array(['Bakery', 'Salads', 'Lunch/Cold Sandwiches',
#        'Protein Boxes & Bowls', 'Lunch/Warm Sandwiches',
#        'Yogurt & Custard', 'Soups', 'Hot Breakfast', 'Biscotti & Cookies',
#        'Chocolates & Candy', 'Fruit & Nuts', 'Popcorn & Chips',
#        'Meat & Cheese', 'Snack Bars', 'Cold Drinks', 'Hot Drinks'],
#       dtype=object)

# %%
SB_menu
# Out:
#     Category         Kind                                          Item  \
# 0       food       Bakery                                  Chonga Bagel
# 1       food       Bakery                                  8-Grain Roll
# 2       food       Bakery                              Almond Croissant
# 3       food       Bakery                              Banana Nut Bread
# 4       food       Bakery                             Birthday Cake Pop
# 5       food       Bakery                              Blueberry Muffin
# 6       food       Bakery                            Blueberry Oat Cake
# 7       food       Bakery                               Blueberry Scone
# 8       food       Bakery                              Butter Croissant
# 9       food       Bakery                                 Cheese Danish
# 10      food       Bakery                            Chocolate Cake Pop
# 212     0.413793        0.137931  0.014728            0.190024    0.142857
# 213     0.310345        0.197044  0.176730            0.190024    0.000000
# 214     0.310345        0.197044  0.176730            0.190024    0.000000
# 215     0.390805        0.315271  0.147275            0.359688    1.142857
# 216     0.298851        0.295567  0.058910            0.407194    1.000000
#
#      d_Protein(g)  d_Sodium(g)
# 0        0.394089     0.938053
# 1        0.328407     0.761062
# 2        0.328407     0.690265
# 3        0.197044     0.566372
# 4        0.032841     0.194690
# 5        0.164204     0.477876
# 6        0.229885     0.761062
# 7        0.164204     0.619469
# 8        0.164204     0.566372
# 9        0.262726     0.707965
# 10       0.065681     0.141593
# 11       0.131363     0.389381
# 12       0.065681     0.141593
# 13       0.197044     0.495575
# 14       0.295567     0.654867
# 15       0.164204     0.477876
# 16       0.131363     0.389381
# 17       0.229885     0.389381
# 18       0.098522     0.495575
# 19       0.361248     0.796460
# 20       0.197044     0.637168
# 21       0.131363     0.247788
# 22       0.065681     0.389381
# 23       0.197044     0.548673
# 24       0.295567     0.778761
# 25       0.164204     0.725664
# 26       0.065681     0.168142
# 27       0.295567     1.097345
# 28       0.197044     0.884956
# 29       0.164204     0.761062
# ..            ...          ...
# 187      0.032841     0.044248
# 188      0.459770     0.283186
# 189      0.394089     0.203540
# 190      0.426929     0.300885
# 191      0.426929     0.247788
# 192      0.262726     0.176991
# 193      0.328407     0.265487
# 194      0.361248     0.265487
# 195      0.394089     0.318584
# 196      0.394089     0.283186
# 197      0.262726     0.203540
# 198      0.295567     0.159292
# 199      0.328407     0.265487
# 200      0.229885     0.168142
# 201      0.361248     0.318584
# 202      0.229885     0.176991
# 203      0.328407     0.336283
# 204      0.394089     0.283186
# 205      0.394089     0.283186
# 206      0.098522     0.070796
# 207      0.394089     0.265487
# 208      0.459770     0.424779
# 209      0.492611     0.000000
# 210      0.098522     0.353982
# 211      0.131363     0.389381
# 212      0.131363     0.318584
# 213      0.328407     0.238938
# 214      0.328407     0.238938
# 215      0.656814     0.300885
# 216      0.525452     0.230088
#
# [217 rows x 21 columns]

# %%
# Let's design the breakfast / dinner formats ('kinds') from above catrgories.

# Example for breakfast for SB_menu: kinds = ['Hot Breakfast', 'Fruit & Nuts', 'Hot Drinks']
kinds=['Hot Breakfast', 'Fruit & Nuts', 'Hot Drinks']

k1, k2, k3 = [], [], []

def kind_lists (row, kinds=['Hot Breakfast', 'Fruit & Nuts', 'Hot Drinks']):
    
    '''making lists of all items that matches with respective kind in 'kinds' format
    3 kind-format --> 3 lists of items'''

    if kinds[0] in row[1]:
        k1.append (row[2])
    if kinds[1] in row[1]:
        k2.append (row[2])
    if kinds[2] in row[1]:
        k3.append (row[2])
    
    return k1,k2,k3
    
kinds=['Hot Breakfast', 'Fruit & Nuts', 'Hot Drinks']
SB_menu.apply (kind_lists, axis=1)

# make all non-repeated element-wise combinations of items (by default of 3 items = len (kinds))
arrays = [k1, k2, k3]
combinator = list(product(*arrays))

# 2340 combinations from these kinds of menu!
combinator
len (combinator)
# Out:
# 2340

# %%
# Let's evaluate all these combinations by their Q-index:
