# %% [markdown]
# # McDonalds and Starbucks: what would be better as meals for teens?
# <b>1. McDonalds (McD) and Starbucks (SB): data processing & exploratory analysis</b>

# %% [markdown]
# DONE:
# 0. Norms values from official document extracted manually --> txt --> dict. We find only 6 values: <b>Energy(kcal), Fat(g), Carbohydrates(g), Fiber(g), Protein(g), Sodium (g)</b>, wich exist in all three datasets: McD, SB menus and <b>[official document (RU)](http://www.normacs.ru/Doclist/doc/11HIP.html)</b> (Table 4.5).
# 1. Values from McD and SB .csv menus --> Excel --> (processing: combine, add features in cols). All mass values converted to same units (g). Girls/boys norms were converted in single norm set (<b>Fiber</b> and <b>Sodium</b> values were same, the rest were averaged).
# 2. Features added: (1) <b>'McD/SB'</b>: restaurant coding, (2) <b>'Category'</b>: food/drink, (3) <b>'Kind'</b>: certain item group, for instance: 'bakery', 'hot breakfast', 'sweets', 'hot drink'. SB have about 2 times more such item groups than McD but the latter have more items per groups.
# 3. Dataset enriched manually: >60 items in <b>'Snacks & sweets'</b> category were added for SB menu. Thus we have more balanced dataaset (McD/SB share).
# 4. Discard from decimal zeroes: dividing all mass values by 1000 (mg --> g).
# 5. Several bug fixes in values.
# 6. Deleted items with all zero values (for instance, <b>Iced Coffee</b>).
# 7. Calculate weighted norms - according the rule requirement from <b>[official document-2 (RU)](https://legalacts.ru/doc/pismo-minobrnauki-rossii-ot-12042012-n-06-731/#100010)</b>: <i>"...for children meals breakfast / dinner share for caloric and nutrition values should be about 25% / 35% of daily total"</i> (p. 6.4). We set 30% / 30% share --> norm for breakfast / dinner =  <b>norms*0.3</b> (only breakfast and dinner were mentioned in the task).
# 8. Deleting items <b>with > 60%</b> (breakfast + dinner total: 'sum_norm' dict) of daily norm caloric or nutrition values (for instance, <b>1880 kcal 40 pieces of chicken McNuggets</b>). Exception: we assume that sodium needs increases due to sport activity: the <b>norm value 0.78 g</b> were update to <b>1.0 g</b> sodium threshold. It allows preserve more items in dataset.
# 9. Exploratory data analysis and visualizations: total counts, values means, several insights.

# %%
# required imports
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.dpi"] = 72  # 144 = better resolution for diagrams

## Saving in eps in good resolution:
# plt.savefig('destination_path.eps', format='eps') 

## To specify the orientation (after plot creating and before plt.savefig call):
# ax.view_init(elev=elevation_angle, azim=azimuthal_angle)

# %% [markdown]
# ### Official norms

# %%
# Dict with actual norms (doc-1)
norms = {}

f = open ('actual_norms.txt')

for line in f:
    line = line.strip().split(',')
    norms[line[0]] = line[1]
    
del norms['Item']
norms
# Out:
# {'Energy(kcal)': '2900',
#  'Fat(g)': '97',
#  'Carbohydrates(g)': '421',
#  'Fiber(g)': '20',
#  'Protein(g)': '87',
#  'Sodium(g)': '1.3'}

# %%
# calculating weighted norms:
meal_norm = {key:float(value)*0.3 for key, value in norms.items()}
    
# sum_norm dict for data filtering (del items with greater values):   
sum_norm = {key:float(value)*0.6 for key, value in norms.items()}
    
print (meal_norm)
print (sum_norm)
# Out:
# {'Energy(kcal)': 870.0, 'Fat(g)': 29.099999999999998, 'Carbohydrates(g)': 126.3, 'Fiber(g)': 6.0, 'Protein(g)': 26.099999999999998, 'Sodium(g)': 0.39}
# {'Energy(kcal)': 1740.0, 'Fat(g)': 58.199999999999996, 'Carbohydrates(g)': 252.6, 'Fiber(g)': 12.0, 'Protein(g)': 52.199999999999996, 'Sodium(g)': 0.78}

# %% [markdown]
# ### McD, SB menus

# %%
# Starbucks (SB) and McDonalds (McD) combined menu in single df: 
menu_df = pd.read_csv ('combined.csv', sep=';', encoding = 'koi8-r')
menu_df.head()
# Out:
#   McD/SB Category    Kind               Item  Energy(kcal)  Fat(g)  \
# 0     SB     food  Bakery       Chonga Bagel           300     5.0
# 1     SB     food  Bakery       8-Grain Roll           380     6.0
# 2     SB     food  Bakery   Almond Croissant           410    22.0
# 3     SB     food  Bakery   Banana Nut Bread           420    22.0
# 4     SB     food  Bakery  Birthday Cake Pop           170     9.0
#
#    Carbohydrates(g)  Fiber(g)  Protein(g)  Sodium(g)
# 0                50       3.0          12       0.53
# 1                70       7.0          10       0.43
# 2                45       3.0          10       0.39
# 3                52       2.0           6       0.32
# 4                23       0.0           1       0.11

# %%
# checking data gaps - it's OK
menu_df.describe()
# Out:
#        Energy(kcal)      Fat(g)  Carbohydrates(g)    Fiber(g)  Protein(g)  \
# count     500.00000  500.000000        500.000000  500.000000  500.000000
# mean      302.72000   11.961000         38.740000    1.841000   10.776000
# std       212.84974   12.144338         25.376215    2.325087   10.325457
# min         0.00000    0.000000          0.000000    0.000000    0.000000
# 25%       140.00000    1.500000         21.750000    0.000000    2.000000
# 50%       270.00000    9.000000         36.000000    1.000000    9.000000
# 75%       430.00000   19.000000         52.000000    3.000000   16.000000
# max      1880.00000  118.000000        141.000000   24.000000   87.000000
#
#         Sodium(g)
# count  500.000000
# mean     0.389510
# std      0.495669
# min      0.000000
# 25%      0.058750
# 50%      0.162500
# 75%      0.590000
# max      3.600000

# %% [markdown]
# ### Clean the data

# %%
# any all-zero items to delete?
del_list = []
def find_zeroes (row):
    
    '''the function recieve row of a df and process it: if all quantitative fields 
    are zeroes in the row, the row included in list for deleting which no returned directly'''
    
    if row[4:].sum() == 0:
        del_list.append (row[3])
        
menu_df.apply (find_zeroes, axis = 1)
menu_df = menu_df.loc[~menu_df['Item'].isin(del_list)]
len (menu_df) # 7 values deleted
# Out:
# 493

# %%
# filtering: del items with values > weighted norm in sum_norm dict:
menu_df[menu_df['Energy(kcal)']>=sum_norm['Energy(kcal)']]
# only 1 item exceeds sum_norms (1740 kcal)
# Out:
#     McD/SB Category     Kind                          Item  Energy(kcal)  \
# 322    McD     food  Burgers  Chicken McNuggets (40 piece)          1880
#
#      Fat(g)  Carbohydrates(g)  Fiber(g)  Protein(g)  Sodium(g)
# 322   118.0               118       6.0          87        3.6

# %%
menu_df[menu_df['Fat(g)']>=sum_norm['Fat(g)']]
# 3 items exceed sum_norms (58.2 g)
# Out:
#     McD/SB Category               Kind                              Item  \
# 272    McD     food  Hot Big Breakfast  BB with Hotcakes (Large Biscuit)
# 321    McD     food            Burgers      Chicken McNuggets (20 piece)
# 322    McD     food            Burgers      Chicken McNuggets (40 piece)
#
#      Energy(kcal)  Fat(g)  Carbohydrates(g)  Fiber(g)  Protein(g)  Sodium(g)
# 272          1150    60.0               116       7.0          36       2.26
# 321           940    59.0                59       3.0          44       1.80
# 322          1880   118.0               118       6.0          87       3.60

# %%
menu_df[menu_df['Carbohydrates(g)']>=sum_norm['Carbohydrates(g)']]
# no items exceed sum_norms
# Out:
# Empty DataFrame
# Columns: [McD/SB, Category, Kind, Item, Energy(kcal), Fat(g), Carbohydrates(g), Fiber(g), Protein(g), Sodium(g)]
# Index: []

# %%
menu_df[menu_df['Fiber(g)']>=sum_norm['Fiber(g)']]
# 2 items exceed sum_norms (12.0 g)
# Out:
#     McD/SB Category                   Kind  \
# 56      SB     food  Protein Boxes & Bowls
# 114     SB     food           Fruit & Nuts
#
#                                                  Item  Energy(kcal)  Fat(g)  \
# 56   Lentils & Vegetable Protein Bowl with Brown Rice           650    29.0
# 114                                 Bare Fruit Medley           130     0.0
#
#      Carbohydrates(g)  Fiber(g)  Protein(g)  Sodium(g)
# 56                 80      21.0          23       0.67
# 114                31      24.0           1       0.00

# %%
menu_df[menu_df['Protein(g)']>=sum_norm['Protein(g)']]
# only 1 item exceeds sum_norms (52.2 g)
# Out:
#     McD/SB Category     Kind                          Item  Energy(kcal)  \
# 322    McD     food  Burgers  Chicken McNuggets (40 piece)          1880
#
#      Fat(g)  Carbohydrates(g)  Fiber(g)  Protein(g)  Sodium(g)
# 322   118.0               118       6.0          87        3.6

# %%
menu_df[menu_df['Sodium(g)']>=sum_norm['Sodium(g)']]
# Wow! 104 items exceed sum_norms (0.78 g)
# Out:
#     McD/SB Category                   Kind  \
# 36      SB     food        Cold Sandwiches
# 37      SB     food        Cold Sandwiches
# 38      SB     food  Protein Boxes & Bowls
# 40      SB     food        Warm Sandwiches
# 41      SB     food        Warm Sandwiches
# 43      SB     food        Cold Sandwiches
# 44      SB     food        Warm Sandwiches
# 45      SB     food        Warm Sandwiches
# 46      SB     food        Warm Sandwiches
# 48      SB     food        Warm Sandwiches
# 49      SB     food                 Salads
# 51      SB     food  Protein Boxes & Bowls
# 52      SB     food  Protein Boxes & Bowls
# 53      SB     food  Protein Boxes & Bowls
# 58      SB     food  Protein Boxes & Bowls
# 61      SB     food          Hot Breakfast
# 62      SB     food          Hot Breakfast
# 64      SB     food          Hot Breakfast
# 68      SB     food          Hot Breakfast
# 69      SB     food          Hot Breakfast
# 70      SB     food          Hot Breakfast
# 75      SB     food          Hot Breakfast
# 76      SB     food          Hot Breakfast
# 77      SB     food        Warm Sandwiches
# 78      SB     food        Warm Sandwiches
# 304                51       4.0          40       1.56
# 307                43       2.0          22       1.26
# 308                41       2.0          20       1.26
# 310                56       3.0          32       1.54
# 311                42       3.0          36       1.37
# 312                56       3.0          27       1.34
# 313                42       3.0          30       1.17
# 314                68       5.0          27       1.48
# 315                55       5.0          31       1.32
# 316                61       3.0          23       1.26
# 317                47       3.0          27       1.09
# 321                59       3.0          44       1.80
# 322               118       6.0          87       3.60
#
# [73 rows x 10 columns]

# %%
# Drop out all items that exceeds the criteria:
menu_df = menu_df[menu_df['Energy(kcal)'] < sum_norm['Energy(kcal)']]
menu_df = menu_df[menu_df['Fat(g)'] < sum_norm['Fat(g)']]
menu_df = menu_df[menu_df['Fiber(g)'] < sum_norm['Fiber(g)']]
menu_df = menu_df[menu_df['Protein(g)'] < sum_norm['Protein(g)']]
menu_df = menu_df[menu_df['Sodium(g)'] < 1.0]

len (menu_df)
# Out:
# 418

# %%
# We increased sodium sum norm 0.78 --> 1.0, i.e. +0.22. 
# In turns it increases sodium meal_norm by 0.11 g. Dicts update: 
meal_norm['Sodium(g)'] += 0.11
sum_norm['Sodium(g)'] += 0.22
print (meal_norm)
print (sum_norm)
# Out:
# {'Energy(kcal)': 870.0, 'Fat(g)': 29.099999999999998, 'Carbohydrates(g)': 126.3, 'Fiber(g)': 6.0, 'Protein(g)': 26.099999999999998, 'Sodium(g)': 0.5}
# {'Energy(kcal)': 1740.0, 'Fat(g)': 58.199999999999996, 'Carbohydrates(g)': 252.6, 'Fiber(g)': 12.0, 'Protein(g)': 52.199999999999996, 'Sodium(g)': 1.0}

# %%
# writing processed dataset in csv
menu_df.to_csv ('combined_processed.csv', index=False)

# %% [markdown]
# ### Visualizations & descriptive stats

# %%
# total food and drinks for each restaurant
menu_df.groupby (['McD/SB','Category']).count()['Kind'].plot.pie(subplots=False, figsize=(5, 5))
# SB have much more food items (136 in 217 total), whereas McD much more drinks (138 in 201 total)

# %%
# All mean caloric values:
means_all = menu_df.groupby (['McD/SB', 'Category', 'Kind']).mean()
means_all['Energy(kcal)'].plot(kind = 'bar', subplots = False, sharex=True, sharey=False, width = 0.6, figsize = (10,4))
# high-energy groups: SB cold sandwiches, Protein boxes, McD Hot big breakfast 
# and (surprisingly) McD sweets/snacks as champion... OK, Google --> it is ice-creams =)

# %%
# Fat, Carbohydrates, Fiber and Protein:
means_all[['Fat(g)', 
          'Carbohydrates(g)', 
          'Fiber(g)', 
          'Protein(g)']].plot(kind = 'bar', subplots = False, sharex=True, sharey=False, width = 0.8, figsize = (17,5))

# McD ice-creams in sweets/snacks overweight all in carbohydrates. Likely it is sugar.
# Leaders on Fat: SB protein boxes and cold sandwiches, McD sweets (ice-creams) 
# and of course burgers. 
# Leaders on Protein: not SB protein boxes as expected. It is SB cold sandwiches which  
# also leaders in Fiber with SB salads (which expected)

# %%
# Sodium on separate graph due to small absolute values:
means_all['Sodium(g)'].plot(kind = 'bar', subplots = False, sharex=True, sharey=False, width = 0.6, figsize = (10,4))
# McD food have more uniform and relatively high values across the main food groups
# SB sodium destribution is highly non-equal across menu, where cold sandwiches reveal highest value

# %%
# full desc stats
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(menu_df.groupby (['McD/SB', 'Category']).describe())
# Out:
#                 Energy(kcal)                                              \
#                        count        mean         std   min    25%    50%
# McD/SB Category
# McD    drink           138.0  290.942029  193.314870   0.0  170.0  260.0
#        food             63.0  347.936508  170.165088  15.0  250.0  340.0
# SB     drink            81.0  145.493827   99.992515   5.0   70.0  130.0
#        food            136.0  252.058824  129.380963  60.0  150.0  230.0
#
#                               Fat(g)                                       \
#                    75%    max  count       mean       std  min  25%   50%
# McD/SB Category
# McD    drink     370.0  850.0  138.0   7.173913  7.947972  0.0  0.0   4.5
#        food      430.0  930.0   63.0  14.777778  8.286589  0.0  8.0  15.0
# SB     drink     200.0  430.0   81.0   3.123457  4.432501  0.0  0.0   0.5
#        food      332.5  600.0  136.0  11.841912  8.026969  0.0  6.0  11.5
#
#                             Carbohydrates(g)                             \
#                   75%   max            count       mean        std  min
# McD/SB Category
# McD    drink     13.0  31.0            138.0  49.500000  30.551918  0.0
#        food      22.0  33.0             63.0  40.730159  25.598139  4.0
# SB     drink      6.0  26.0             81.0  24.851852  15.487988  0.0
#        food      18.0  32.0            136.0  29.919118  17.019403  0.0
#
#                                           Fiber(g)                           \
#                    25%   50%   75%    max    count      mean       std  min
# McD/SB Category
# McD    drink     28.25  48.5  65.0  141.0    138.0  0.768116  0.906504  0.0
#        food      27.50  34.0  51.0  139.0     63.0  2.285714  1.640501  0.0
# SB     drink     14.00  23.0  35.0   64.0     81.0  0.604938  1.715219  0.0
#        food      18.00  27.0  42.0   71.0    136.0  2.444853  2.128008  0.0
#
#                                      Protein(g)                            \
#                  25%  50%  75%   max      count       mean       std  min
# McD/SB Category
# McD    drink     0.0  1.0  1.0   5.0      138.0   7.782609  5.958174  0.0
#        food      1.0  2.0  3.0   7.0       63.0  13.317460  8.220402  0.0
# SB     drink     0.0  0.0  0.0   8.0       81.0   4.901235  5.750228  0.0
#        food      1.0  2.0  3.0  11.0      136.0   7.779412  7.013945  0.0
#
#                                        Sodium(g)                           \
#                  25%   50%   75%   max     count      mean       std  min
# McD/SB Category
# McD    drink     1.0   9.0  12.0  19.0     138.0  0.125036  0.082673  0.0
#        food      6.0  14.0  21.0  29.0      63.0  0.513175  0.330011  0.0
# SB     drink     0.0   2.0  10.0  20.0      81.0  0.071111  0.075519  0.0
#        food      3.0   5.0  11.0  32.0     136.0  0.277022  0.267558  0.0
#
#
#                    25%    50%     75%   max
# McD/SB Category
# McD    drink     0.050  0.135  0.1800  0.38
#        food      0.175  0.590  0.8050  0.99
# SB     drink     0.010  0.030  0.1350  0.33
#        food      0.065  0.180  0.4425  0.95

# %%
stats = menu_df.groupby (['McD/SB', 'Category']).describe()
# CALORIES: mean, std, min, 25%, 50%, 75%, max
stats.iloc[:,1:8].plot (kind='bar', subplots=False, legend=True, figsize=(12,4), width = 0.6)
# mean ≈ median for all groups: it is likely that the value fits normal distribution in all groups

# %%
# FAT: mean, std, min, 25%, 50%, 75%, max
stats.iloc[:,9:16].plot (kind='bar', subplots=False, legend=True, figsize=(12,4), width = 0.6)
# mean ≈ median just for food. It is likely that drinks in both SB and McD have several items 
# with high values (outliers), as mean > median and mean < std

# %%
# CARBOHYDRATES: mean, std, min, 25%, 50%, 75%, max
stats.iloc[:,17:24].plot (kind='bar', subplots=False, legend=True, figsize=(12,4), width = 0.6)
# mean ≈ median for all groups (slightly exceess)

# %%
# FIBER: mean, std, min, 25%, 50%, 75%, max
stats.iloc[0:,25:32].plot (kind='bar', subplots=False, legend=True, figsize=(12,4), width = 0.6)
# mean ≈ median just for food (with zero value in drinks, as one could expect)

# %%
# PROTEIN: mean, std, min, 25%, 50%, 75%, max
stats.iloc[0:,33:40].plot (kind='bar', subplots=False, legend=True, figsize=(12,4), width = 0.6)
# for McD mean slightly < median, for SB vice versa. Seems that SB food have more outliers - 
# items with relative high protein contains (or groups with protein-rich items). 
# Nevertheless, McD overwight in absolute mean & median values

# %%
# SODIUM: mean, std, min, 25%, 50%, 75%, max
stats.iloc[0:,41:48].plot (kind='bar', subplots=False, legend=True, figsize=(12,4), width = 0.6)
# the same situation as with proteins, which is more it is tendency also for drinks

# %% [markdown]
# Finally, it seems that <b>SB menu have more frequently have high std</b> (which sometimes exceeds mean). For drinks it could be explained that this SB group much lesser then respctive McD group. But food repeat same tendency. McD menu seems <b>more uniform for groups and with less values variation</b>.

# %%
# CALORIES means share for four groups
stats['Energy(kcal)']['mean'].plot.pie(y ='Energy(kcal)', subplots=False, figsize=(5, 5), legend=False)
# McD items much more caloric-rich in average

# %%
# FAT means shares for four groups
stats['Fat(g)']['mean'].plot.pie(y='Fat(g)', subplots=False, figsize=(5, 5), legend=False)
# ... and this caloric richness may be caused by fat

# %%
# CARBOHYDRATES means shares for four groups
stats['Carbohydrates(g)']['mean'].plot.pie(y='Carbohydrates(g)', subplots=False, figsize=(5, 5),legend=False)
# ... and carbohydrates

# %%
# FIBER means shares for four groups
stats['Fiber(g)']['mean'].plot.pie(y='Fiber(g)', subplots=False, figsize=(5, 5),legend=False)
# whereas SB ≈ McD in average fiber

# %%
# PROTEIN means shares for four groups
stats['Protein(g)']['mean'].plot.pie(y='Protein(g)', subplots=False, figsize=(5, 5),legend=False)
# protein resembles the same pattern as fat and carbohydrates

# %%
# SODIUM means shares for four groups
stats['Sodium(g)']['mean'].plot.pie(y='Sodium(g)', subplots=False, figsize=(5, 5),legend=False)
# ... and sodium also

# %% [markdown]
# So McD food and drinks exceed SB ones on average <b>calories, fat, carbohydrates, protein and sodium</b>. On this values <b>McD : SB ≈ 60 : 40</b>, whereas <b>fiber</b> ratio close to <b>50 : 50</b>
